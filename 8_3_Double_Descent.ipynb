# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-4hy4nvsi
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-4hy4nvsi
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (3.9.0)
# Requirement already satisfied: scipy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'mps'))
print('Using:', DEVICE)
# Out:
# Using: mps

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.297951, train error 89.93,  test loss 2.299305, test error 90.18
# Epoch   100, train loss 1.910366, train error 71.70,  test loss 1.761613, test error 69.80
# Epoch   200, train loss 1.903344, train error 72.03,  test loss 1.741333, test error 69.82
# Epoch   300, train loss 1.899845, train error 71.82,  test loss 1.737978, test error 69.93
# Epoch   400, train loss 1.901446, train error 70.93,  test loss 1.746243, test error 69.57
# Epoch   500, train loss 1.899075, train error 71.53,  test loss 1.734761, test error 70.10
# Epoch   600, train loss 1.898957, train error 71.60,  test loss 1.736110, test error 69.88
# Epoch   700, train loss 1.899076, train error 71.07,  test loss 1.734918, test error 69.70
# Epoch   800, train loss 1.898461, train error 71.78,  test loss 1.730876, test error 69.78
# Epoch   900, train loss 1.897312, train error 71.43,  test loss 1.730117, test error 69.07
# Training model with   4 hidden variables
# Epoch     0, train loss 2.265369, train error 86.97,  test loss 2.258744, test error 86.90
# Epoch   100, train loss 1.767793, train error 64.80,  test loss 1.609911, test error 63.03
# Epoch   200, train loss 1.753715, train error 65.43,  test loss 1.597174, test error 62.90
# Epoch   300, train loss 1.753484, train error 64.88,  test loss 1.610379, test error 63.12
# Epoch   400, train loss 1.749407, train error 64.30,  test loss 1.606497, test error 61.95
# Epoch   500, train loss 1.748261, train error 64.55,  test loss 1.613142, test error 62.78
# Epoch   600, train loss 1.745758, train error 64.18,  test loss 1.622108, test error 63.40
# Epoch   700, train loss 1.752027, train error 65.30,  test loss 1.625860, test error 62.80
# Epoch   800, train loss 1.739218, train error 63.75,  test loss 1.625843, test error 62.83
# Epoch   900, train loss 1.738325, train error 63.78,  test loss 1.637728, test error 61.92
# Training model with   6 hidden variables
# Epoch     0, train loss 2.294610, train error 87.78,  test loss 2.303394, test error 88.85
# Epoch   100, train loss 1.695237, train error 61.08,  test loss 1.500579, test error 58.15
# Epoch   200, train loss 1.665707, train error 58.53,  test loss 1.472420, test error 55.85
# Epoch   300, train loss 1.654445, train error 59.25,  test loss 1.455858, test error 55.70
# Epoch   400, train loss 1.652073, train error 58.62,  test loss 1.464296, test error 55.45
# Epoch   500, train loss 1.653640, train error 59.00,  test loss 1.460585, test error 56.03
# Epoch   600, train loss 1.646602, train error 58.25,  test loss 1.457934, test error 55.10
# Epoch   700, train loss 1.649916, train error 58.47,  test loss 1.446718, test error 55.05
# Epoch   800, train loss 1.642990, train error 58.67,  test loss 1.450580, test error 55.33
# Epoch   900, train loss 1.647159, train error 58.85,  test loss 1.460053, test error 56.58
# Training model with   8 hidden variables
# Epoch     0, train loss 2.316184, train error 88.05,  test loss 2.306438, test error 87.43
# Epoch   100, train loss 1.647585, train error 59.25,  test loss 1.508849, test error 58.42
# Epoch   200, train loss 1.620435, train error 57.30,  test loss 1.511668, test error 59.30
# Epoch   300, train loss 1.609208, train error 56.53,  test loss 1.522042, test error 59.17
# Epoch   400, train loss 1.596738, train error 56.58,  test loss 1.516492, test error 58.85
# Epoch   500, train loss 1.595455, train error 56.65,  test loss 1.530593, test error 58.90
# Epoch   600, train loss 1.587763, train error 57.17,  test loss 1.513279, test error 58.33
# Epoch   700, train loss 1.579122, train error 56.12,  test loss 1.519103, test error 58.35
# Epoch   800, train loss 1.574331, train error 56.97,  test loss 1.521124, test error 58.20
# Epoch   900, train loss 1.568183, train error 56.72,  test loss 1.517259, test error 58.33
# Training model with  10 hidden variables
# Epoch     0, train loss 2.249837, train error 85.62,  test loss 2.250028, test error 85.82
# Epoch   100, train loss 1.573769, train error 54.88,  test loss 1.438598, test error 55.30
# Epoch   200, train loss 1.509144, train error 52.22,  test loss 1.409140, test error 53.53
# Epoch   300, train loss 1.488510, train error 51.70,  test loss 1.395627, test error 52.78
# Epoch   400, train loss 1.464263, train error 50.90,  test loss 1.382104, test error 52.40
# Epoch   500, train loss 1.446466, train error 50.38,  test loss 1.386597, test error 51.67
# Epoch   600, train loss 1.441925, train error 50.25,  test loss 1.391698, test error 51.47
# Epoch   700, train loss 1.430299, train error 49.47,  test loss 1.388223, test error 51.53
# Epoch   800, train loss 1.435145, train error 49.60,  test loss 1.398896, test error 52.03
# Epoch   900, train loss 1.421654, train error 48.80,  test loss 1.386174, test error 50.95
# Training model with  14 hidden variables
# Epoch     0, train loss 2.209337, train error 81.85,  test loss 2.196451, test error 81.75
# Epoch   100, train loss 1.386763, train error 46.10,  test loss 1.252751, test error 46.45
# Epoch   200, train loss 1.314420, train error 43.20,  test loss 1.245113, test error 45.72
# Epoch   300, train loss 1.289429, train error 43.30,  test loss 1.273293, test error 46.28
# Epoch   400, train loss 1.276255, train error 42.75,  test loss 1.301092, test error 46.33
# Epoch   500, train loss 1.256425, train error 41.75,  test loss 1.301479, test error 46.58
# Epoch   600, train loss 1.246821, train error 41.42,  test loss 1.341594, test error 46.62
# Epoch   700, train loss 1.241166, train error 41.90,  test loss 1.346576, test error 46.60
# Epoch   800, train loss 1.231359, train error 41.40,  test loss 1.362890, test error 46.78
# Epoch   900, train loss 1.225291, train error 41.65,  test loss 1.370234, test error 47.92
# Training model with  18 hidden variables
# Epoch     0, train loss 2.232878, train error 83.97,  test loss 2.214231, test error 84.60
# Epoch   100, train loss 1.370595, train error 46.12,  test loss 1.367862, test error 51.03
# Epoch   200, train loss 1.272224, train error 43.17,  test loss 1.408825, test error 51.45
# Epoch   300, train loss 1.224302, train error 41.25,  test loss 1.464876, test error 51.70
# Epoch   400, train loss 1.214870, train error 41.72,  test loss 1.498729, test error 51.92
# Epoch   500, train loss 1.201128, train error 40.83,  test loss 1.532729, test error 52.10
# Epoch   600, train loss 1.193336, train error 40.55,  test loss 1.539204, test error 52.17
# Epoch   700, train loss 1.194023, train error 40.17,  test loss 1.576721, test error 52.60
# Epoch   800, train loss 1.181911, train error 40.17,  test loss 1.581214, test error 52.92
# Epoch   900, train loss 1.178514, train error 40.38,  test loss 1.591920, test error 52.30
# Training model with  22 hidden variables
# Epoch     0, train loss 2.164016, train error 80.95,  test loss 2.107890, test error 78.43
# Epoch   100, train loss 1.259193, train error 42.45,  test loss 1.337088, test error 48.95
# Epoch   200, train loss 1.159702, train error 39.05,  test loss 1.373472, test error 48.92
# Epoch   300, train loss 1.096878, train error 36.60,  test loss 1.422131, test error 49.30
# Epoch   400, train loss 1.038229, train error 34.03,  test loss 1.477567, test error 50.28
# Epoch   500, train loss 1.018163, train error 33.22,  test loss 1.571072, test error 51.67
# Epoch   600, train loss 0.999784, train error 32.30,  test loss 1.588701, test error 51.30
# Epoch   700, train loss 0.992963, train error 32.80,  test loss 1.629466, test error 51.10
# Epoch   800, train loss 0.986837, train error 33.05,  test loss 1.642675, test error 50.90
# Epoch   900, train loss 0.978698, train error 33.28,  test loss 1.678625, test error 51.60
# Training model with  26 hidden variables
# Epoch     0, train loss 2.212625, train error 80.90,  test loss 2.201612, test error 80.65
# Epoch   100, train loss 1.205546, train error 40.28,  test loss 1.372205, test error 51.25
# Epoch   200, train loss 1.049651, train error 34.90,  test loss 1.489120, test error 50.88
# Epoch   300, train loss 0.974222, train error 32.82,  test loss 1.623706, test error 52.00
# Epoch   400, train loss 0.929217, train error 31.80,  test loss 1.769198, test error 53.42
# Epoch   500, train loss 0.904309, train error 31.85,  test loss 1.896490, test error 54.90
# Epoch   600, train loss 0.879318, train error 30.75,  test loss 1.975659, test error 54.22
# Epoch   700, train loss 0.863424, train error 29.90,  test loss 2.070273, test error 55.55
# Epoch   800, train loss 0.844842, train error 29.12,  test loss 2.133075, test error 55.92
# Epoch   900, train loss 0.840972, train error 28.03,  test loss 2.211651, test error 55.53
# Training model with  30 hidden variables
# Epoch     0, train loss 2.179863, train error 79.25,  test loss 2.154903, test error 78.47
# Epoch   100, train loss 1.103827, train error 36.65,  test loss 1.322819, test error 48.17
# Epoch   200, train loss 0.944333, train error 31.32,  test loss 1.544466, test error 50.47
# Epoch   300, train loss 0.857724, train error 28.20,  test loss 1.715466, test error 51.17
# Epoch   400, train loss 0.781071, train error 26.03,  test loss 1.882523, test error 52.67
# Epoch   500, train loss 0.729373, train error 24.47,  test loss 2.040176, test error 53.08
# Epoch   600, train loss 0.705487, train error 23.78,  test loss 2.188456, test error 53.47
# Epoch   700, train loss 0.676152, train error 22.62,  test loss 2.295138, test error 54.35
# Epoch   800, train loss 0.673209, train error 22.78,  test loss 2.459425, test error 55.20
# Epoch   900, train loss 0.648228, train error 21.78,  test loss 2.556665, test error 54.60
# Training model with  35 hidden variables
# Epoch     0, train loss 2.138605, train error 79.62,  test loss 2.108949, test error 78.72
# Epoch   100, train loss 1.000768, train error 33.28,  test loss 1.393718, test error 49.65
# Epoch   200, train loss 0.811218, train error 26.90,  test loss 1.743916, test error 52.38
# Epoch   300, train loss 0.676546, train error 21.93,  test loss 2.122014, test error 54.47
# Epoch   400, train loss 0.627899, train error 21.18,  test loss 2.449615, test error 55.67
# Epoch   500, train loss 0.568772, train error 18.97,  test loss 2.747991, test error 55.35
# Epoch   600, train loss 0.543698, train error 18.62,  test loss 3.083218, test error 56.17
# Epoch   700, train loss 0.513829, train error 18.28,  test loss 3.357342, test error 56.05
# Epoch   800, train loss 0.512848, train error 18.05,  test loss 3.683368, test error 57.28
# Epoch   900, train loss 0.448911, train error 15.53,  test loss 3.926572, test error 56.90
# Training model with  40 hidden variables
# Epoch     0, train loss 2.100688, train error 76.85,  test loss 2.065170, test error 76.70
# Epoch   100, train loss 0.897173, train error 28.53,  test loss 1.418488, test error 49.15
# Epoch   200, train loss 0.623130, train error 19.75,  test loss 1.943573, test error 51.50
# Epoch   300, train loss 0.519340, train error 17.03,  test loss 2.561809, test error 53.05
# Epoch   400, train loss 0.417597, train error 13.85,  test loss 3.217915, test error 54.15
# Epoch   500, train loss 0.343632, train error 11.40,  test loss 3.962034, test error 56.05
# Epoch   600, train loss 0.290241, train error 10.32,  test loss 4.705551, test error 55.85
# Epoch   700, train loss 0.253590, train error 8.88,  test loss 5.521006, test error 56.67
# Epoch   800, train loss 0.243630, train error 8.57,  test loss 6.178838, test error 57.03
# Epoch   900, train loss 0.262389, train error 9.68,  test loss 6.863862, test error 56.97
# Training model with  45 hidden variables
# Epoch     0, train loss 2.090993, train error 78.28,  test loss 2.043486, test error 77.30
# Epoch   100, train loss 0.859885, train error 28.22,  test loss 1.615169, test error 52.85
# Epoch   200, train loss 0.521501, train error 16.95,  test loss 2.408102, test error 55.80
# Epoch   300, train loss 0.307290, train error 9.03,  test loss 3.553741, test error 57.42
# Epoch   400, train loss 0.190050, train error 5.18,  test loss 5.001158, test error 58.28
# Epoch   500, train loss 0.147773, train error 4.68,  test loss 6.392864, test error 57.58
# Epoch   600, train loss 0.159026, train error 5.57,  test loss 7.558743, test error 57.55
# Epoch   700, train loss 0.120863, train error 4.47,  test loss 8.637809, test error 57.90
# Epoch   800, train loss 0.008446, train error 0.00,  test loss 9.562946, test error 57.80
# Epoch   900, train loss 0.005732, train error 0.00,  test loss 10.159936, test error 57.92
# Training model with  50 hidden variables
# Epoch     0, train loss 2.086634, train error 77.32,  test loss 1.998705, test error 75.95
# Epoch   100, train loss 0.733513, train error 23.15,  test loss 1.595676, test error 50.40
# Epoch   200, train loss 0.348508, train error 10.20,  test loss 2.660142, test error 53.75
# Epoch   300, train loss 0.154312, train error 3.75,  test loss 4.249835, test error 54.88
# Epoch   400, train loss 0.027366, train error 0.00,  test loss 5.723517, test error 54.58
# Epoch   500, train loss 0.012500, train error 0.00,  test loss 6.627967, test error 54.58
# Epoch   600, train loss 0.008068, train error 0.00,  test loss 7.217131, test error 54.78
# Epoch   700, train loss 0.005765, train error 0.00,  test loss 7.656615, test error 54.72
# Epoch   800, train loss 0.004479, train error 0.00,  test loss 8.014268, test error 54.85
# Epoch   900, train loss 0.003628, train error 0.00,  test loss 8.317055, test error 54.92
# Training model with  55 hidden variables
# Epoch     0, train loss 2.052670, train error 76.85,  test loss 1.986313, test error 75.43
# Epoch   100, train loss 0.662825, train error 20.10,  test loss 1.680344, test error 51.70
# Epoch   200, train loss 0.252235, train error 6.00,  test loss 2.967648, test error 55.12
# Epoch   300, train loss 0.056399, train error 0.20,  test loss 4.593120, test error 55.30
# Epoch   400, train loss 0.016605, train error 0.00,  test loss 5.738988, test error 54.72
# Epoch   500, train loss 0.009077, train error 0.00,  test loss 6.404698, test error 55.08
# Epoch   600, train loss 0.006129, train error 0.00,  test loss 6.876210, test error 55.35
# Epoch   700, train loss 0.004533, train error 0.00,  test loss 7.234774, test error 55.55
# Epoch   800, train loss 0.003568, train error 0.00,  test loss 7.521177, test error 55.58
# Epoch   900, train loss 0.002911, train error 0.00,  test loss 7.764310, test error 55.53
# Training model with  60 hidden variables
# Epoch     0, train loss 2.041544, train error 76.85,  test loss 1.979989, test error 76.50
# Epoch   100, train loss 0.519874, train error 15.85,  test loss 1.732789, test error 50.55
# Epoch   200, train loss 0.112320, train error 1.43,  test loss 3.367935, test error 53.53
# Epoch   300, train loss 0.019345, train error 0.00,  test loss 4.662461, test error 54.28
# Epoch   400, train loss 0.009402, train error 0.00,  test loss 5.319434, test error 54.35
# Epoch   500, train loss 0.005948, train error 0.00,  test loss 5.751103, test error 54.22
# Epoch   600, train loss 0.004250, train error 0.00,  test loss 6.074623, test error 54.10
# Epoch   700, train loss 0.003270, train error 0.00,  test loss 6.331018, test error 54.20
# Epoch   800, train loss 0.002661, train error 0.00,  test loss 6.546753, test error 54.25
# Epoch   900, train loss 0.002197, train error 0.00,  test loss 6.728728, test error 54.33
# Training model with  70 hidden variables
# Epoch     0, train loss 2.039015, train error 75.30,  test loss 1.991388, test error 74.75
# Epoch   100, train loss 0.383359, train error 9.12,  test loss 1.883370, test error 49.10
# Epoch   200, train loss 0.037052, train error 0.00,  test loss 3.635693, test error 53.00
# Epoch   300, train loss 0.011357, train error 0.00,  test loss 4.469536, test error 53.22
# Epoch   400, train loss 0.006301, train error 0.00,  test loss 4.934427, test error 53.20
# Epoch   500, train loss 0.004217, train error 0.00,  test loss 5.256369, test error 53.28
# Epoch   600, train loss 0.003104, train error 0.00,  test loss 5.497378, test error 53.28
# Epoch   700, train loss 0.002432, train error 0.00,  test loss 5.695198, test error 53.40
# Epoch   800, train loss 0.001986, train error 0.00,  test loss 5.858943, test error 53.42
# Epoch   900, train loss 0.001669, train error 0.00,  test loss 5.999270, test error 53.35
# Training model with  80 hidden variables
# Epoch     0, train loss 2.018835, train error 75.72,  test loss 1.924053, test error 73.32
# Epoch   100, train loss 0.236001, train error 4.55,  test loss 2.008699, test error 50.65
# Epoch   200, train loss 0.020459, train error 0.00,  test loss 3.316326, test error 51.42
# Epoch   300, train loss 0.008022, train error 0.00,  test loss 3.847173, test error 51.50
# Epoch   400, train loss 0.004731, train error 0.00,  test loss 4.170563, test error 51.70
# Epoch   500, train loss 0.003264, train error 0.00,  test loss 4.395187, test error 51.75
# Epoch   600, train loss 0.002456, train error 0.00,  test loss 4.571321, test error 51.90
# Epoch   700, train loss 0.001946, train error 0.00,  test loss 4.714753, test error 52.12
# Epoch   800, train loss 0.001605, train error 0.00,  test loss 4.834614, test error 52.08
# Epoch   900, train loss 0.001356, train error 0.00,  test loss 4.938902, test error 52.10
# Training model with  90 hidden variables
# Epoch     0, train loss 1.995610, train error 73.53,  test loss 1.918229, test error 72.60
# Epoch   100, train loss 0.153634, train error 1.57,  test loss 2.150445, test error 51.90
# Epoch   200, train loss 0.015424, train error 0.00,  test loss 3.217294, test error 52.10
# Epoch   300, train loss 0.006774, train error 0.00,  test loss 3.657503, test error 52.12
# Epoch   400, train loss 0.004109, train error 0.00,  test loss 3.927041, test error 52.25
# Epoch   500, train loss 0.002882, train error 0.00,  test loss 4.120734, test error 52.20
# Epoch   600, train loss 0.002186, train error 0.00,  test loss 4.268371, test error 52.28
# Epoch   700, train loss 0.001746, train error 0.00,  test loss 4.391841, test error 52.40
# Epoch   800, train loss 0.001444, train error 0.00,  test loss 4.497357, test error 52.42
# Epoch   900, train loss 0.001225, train error 0.00,  test loss 4.587513, test error 52.45
# Training model with 100 hidden variables
# Epoch     0, train loss 1.978248, train error 72.60,  test loss 1.911237, test error 73.75
# Epoch   100, train loss 0.088059, train error 0.22,  test loss 2.229997, test error 52.03
# Epoch   200, train loss 0.012084, train error 0.00,  test loss 3.091270, test error 51.88
# Epoch   300, train loss 0.005649, train error 0.00,  test loss 3.446057, test error 51.85
# Epoch   400, train loss 0.003535, train error 0.00,  test loss 3.675540, test error 51.95
# Epoch   500, train loss 0.002516, train error 0.00,  test loss 3.839383, test error 51.80
# Epoch   600, train loss 0.001926, train error 0.00,  test loss 3.970459, test error 51.67
# Epoch   700, train loss 0.001549, train error 0.00,  test loss 4.078322, test error 51.67
# Epoch   800, train loss 0.001287, train error 0.00,  test loss 4.170000, test error 51.83
# Epoch   900, train loss 0.001097, train error 0.00,  test loss 4.249915, test error 51.80
# Training model with 120 hidden variables
# Epoch     0, train loss 1.968533, train error 73.00,  test loss 1.895343, test error 71.97
# Epoch   100, train loss 0.048256, train error 0.00,  test loss 2.177002, test error 49.30
# Epoch   200, train loss 0.009364, train error 0.00,  test loss 2.765748, test error 49.80
# Epoch   300, train loss 0.004658, train error 0.00,  test loss 3.034985, test error 49.72
# Epoch   400, train loss 0.002995, train error 0.00,  test loss 3.209906, test error 49.75
# Epoch   500, train loss 0.002161, train error 0.00,  test loss 3.339605, test error 49.78
# Epoch   600, train loss 0.001672, train error 0.00,  test loss 3.443411, test error 49.95
# Epoch   700, train loss 0.001354, train error 0.00,  test loss 3.528791, test error 49.83
# Epoch   800, train loss 0.001131, train error 0.00,  test loss 3.602503, test error 49.75
# Epoch   900, train loss 0.000967, train error 0.00,  test loss 3.666451, test error 49.80
# Training model with 140 hidden variables
# Epoch     0, train loss 1.947531, train error 72.32,  test loss 1.838494, test error 72.90
# Epoch   100, train loss 0.037632, train error 0.00,  test loss 2.206598, test error 49.92
# Epoch   200, train loss 0.008319, train error 0.00,  test loss 2.722647, test error 50.15
# Epoch   300, train loss 0.004228, train error 0.00,  test loss 2.962829, test error 50.20
# Epoch   400, train loss 0.002741, train error 0.00,  test loss 3.120878, test error 50.08
# Epoch   500, train loss 0.001990, train error 0.00,  test loss 3.237278, test error 50.10
# Epoch   600, train loss 0.001546, train error 0.00,  test loss 3.331342, test error 50.12
# Epoch   700, train loss 0.001254, train error 0.00,  test loss 3.408567, test error 50.17
# Epoch   800, train loss 0.001049, train error 0.00,  test loss 3.474390, test error 50.08
# Epoch   900, train loss 0.000898, train error 0.00,  test loss 3.531162, test error 50.12
# Training model with 160 hidden variables
# Epoch     0, train loss 1.922170, train error 70.95,  test loss 1.844382, test error 71.43
# Epoch   100, train loss 0.027708, train error 0.00,  test loss 2.071438, test error 48.65
# Epoch   200, train loss 0.007107, train error 0.00,  test loss 2.457967, test error 48.58
# Epoch   300, train loss 0.003757, train error 0.00,  test loss 2.653267, test error 48.62
# Epoch   400, train loss 0.002476, train error 0.00,  test loss 2.782471, test error 48.55
# Epoch   500, train loss 0.001816, train error 0.00,  test loss 2.879048, test error 48.45
# Epoch   600, train loss 0.001419, train error 0.00,  test loss 2.956748, test error 48.40
# Epoch   700, train loss 0.001156, train error 0.00,  test loss 3.020774, test error 48.40
# Epoch   800, train loss 0.000971, train error 0.00,  test loss 3.075427, test error 48.38
# Epoch   900, train loss 0.000834, train error 0.00,  test loss 3.122864, test error 48.40
# Training model with 180 hidden variables
# Epoch     0, train loss 1.920826, train error 69.62,  test loss 1.847318, test error 72.68
# Epoch   100, train loss 0.024328, train error 0.00,  test loss 2.107339, test error 49.03
# Epoch   200, train loss 0.006546, train error 0.00,  test loss 2.466666, test error 48.62
# Epoch   300, train loss 0.003511, train error 0.00,  test loss 2.645027, test error 48.75
# Epoch   400, train loss 0.002325, train error 0.00,  test loss 2.766387, test error 48.67
# Epoch   500, train loss 0.001711, train error 0.00,  test loss 2.857196, test error 48.62
# Epoch   600, train loss 0.001340, train error 0.00,  test loss 2.930790, test error 48.67
# Epoch   700, train loss 0.001094, train error 0.00,  test loss 2.991392, test error 48.62
# Epoch   800, train loss 0.000920, train error 0.00,  test loss 3.043294, test error 48.70
# Epoch   900, train loss 0.000790, train error 0.00,  test loss 3.088269, test error 48.58
# Training model with 200 hidden variables
# Epoch     0, train loss 1.908133, train error 70.60,  test loss 1.862146, test error 72.35
# Epoch   100, train loss 0.020535, train error 0.00,  test loss 2.038260, test error 48.67
# Epoch   200, train loss 0.005960, train error 0.00,  test loss 2.357643, test error 48.75
# Epoch   300, train loss 0.003249, train error 0.00,  test loss 2.522072, test error 48.62
# Epoch   400, train loss 0.002167, train error 0.00,  test loss 2.631956, test error 48.53
# Epoch   500, train loss 0.001603, train error 0.00,  test loss 2.717051, test error 48.60
# Epoch   600, train loss 0.001259, train error 0.00,  test loss 2.784868, test error 48.65
# Epoch   700, train loss 0.001030, train error 0.00,  test loss 2.841540, test error 48.60
# Epoch   800, train loss 0.000868, train error 0.00,  test loss 2.889648, test error 48.62
# Epoch   900, train loss 0.000747, train error 0.00,  test loss 2.931784, test error 48.60
# Training model with 250 hidden variables
# Epoch     0, train loss 1.886293, train error 68.90,  test loss 1.806307, test error 70.32
# Epoch   100, train loss 0.016913, train error 0.00,  test loss 2.010264, test error 48.55
# Epoch   200, train loss 0.005334, train error 0.00,  test loss 2.275232, test error 48.35
# Epoch   300, train loss 0.002967, train error 0.00,  test loss 2.416929, test error 48.10
# Epoch   400, train loss 0.002006, train error 0.00,  test loss 2.514054, test error 48.25
# Epoch   500, train loss 0.001494, train error 0.00,  test loss 2.587198, test error 48.15
# Epoch   600, train loss 0.001180, train error 0.00,  test loss 2.647518, test error 48.25
# Epoch   700, train loss 0.000969, train error 0.00,  test loss 2.697153, test error 48.30
# Epoch   800, train loss 0.000818, train error 0.00,  test loss 2.740135, test error 48.33
# Epoch   900, train loss 0.000706, train error 0.00,  test loss 2.777396, test error 48.33
# Training model with 300 hidden variables
# Epoch     0, train loss 1.877601, train error 68.15,  test loss 1.812393, test error 72.00
# Epoch   100, train loss 0.014488, train error 0.00,  test loss 1.884397, test error 47.62
# Epoch   200, train loss 0.004782, train error 0.00,  test loss 2.104759, test error 47.12
# Epoch   300, train loss 0.002709, train error 0.00,  test loss 2.227672, test error 47.33
# Epoch   400, train loss 0.001847, train error 0.00,  test loss 2.311652, test error 47.45
# Epoch   500, train loss 0.001383, train error 0.00,  test loss 2.375414, test error 47.45
# Epoch   600, train loss 0.001096, train error 0.00,  test loss 2.427398, test error 47.42
# Epoch   700, train loss 0.000903, train error 0.00,  test loss 2.470533, test error 47.35
# Epoch   800, train loss 0.000764, train error 0.00,  test loss 2.508310, test error 47.38
# Epoch   900, train loss 0.000660, train error 0.00,  test loss 2.540887, test error 47.33
# Training model with 400 hidden variables
# Epoch     0, train loss 1.893111, train error 69.47,  test loss 1.855606, test error 71.93
# Epoch   100, train loss 0.011853, train error 0.00,  test loss 1.759976, test error 45.62
# Epoch   200, train loss 0.004221, train error 0.00,  test loss 1.938363, test error 45.35
# Epoch   300, train loss 0.002444, train error 0.00,  test loss 2.037817, test error 45.33
# Epoch   400, train loss 0.001684, train error 0.00,  test loss 2.106530, test error 45.28
# Epoch   500, train loss 0.001268, train error 0.00,  test loss 2.159041, test error 45.42
# Epoch   600, train loss 0.001010, train error 0.00,  test loss 2.202060, test error 45.35
# Epoch   700, train loss 0.000835, train error 0.00,  test loss 2.238270, test error 45.38
# Epoch   800, train loss 0.000709, train error 0.00,  test loss 2.269132, test error 45.38
# Epoch   900, train loss 0.000614, train error 0.00,  test loss 2.296705, test error 45.33

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
