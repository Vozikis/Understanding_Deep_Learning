# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)                  # no ReLU here

    r1 = self.linear2(h1.relu())          # ReLU BEFORE linear2
    h2 = h1 + r1                          # no ReLU after sum

    r2 = self.linear3(h2.relu())          # ReLU BEFORE linear3
    h3 = h2 + r2                          # no ReLU after sum

    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.671307, train error 62.17,  val loss 1.798094, percent error 67.00
# Epoch     1, train loss 1.149787, train error 43.12,  val loss 1.339207, percent error 52.00
# Epoch     2, train loss 0.986151, train error 37.38,  val loss 1.192587, percent error 44.80
# Epoch     3, train loss 0.877444, train error 33.40,  val loss 1.176409, percent error 42.20
# Epoch     4, train loss 0.808024, train error 31.03,  val loss 1.140525, percent error 42.50
# Epoch     5, train loss 0.750418, train error 29.28,  val loss 1.183349, percent error 42.70
# Epoch     6, train loss 0.624606, train error 23.40,  val loss 1.122007, percent error 41.00
# Epoch     7, train loss 0.606244, train error 23.15,  val loss 1.134552, percent error 41.10
# Epoch     8, train loss 0.550049, train error 20.30,  val loss 1.202016, percent error 40.40
# Epoch     9, train loss 0.553488, train error 20.65,  val loss 1.283175, percent error 40.70
# Epoch    10, train loss 0.470287, train error 16.97,  val loss 1.212328, percent error 39.40
# Epoch    11, train loss 0.482353, train error 17.62,  val loss 1.243376, percent error 36.40
# Epoch    12, train loss 0.350331, train error 13.40,  val loss 1.234722, percent error 35.90
# Epoch    13, train loss 0.434915, train error 16.03,  val loss 1.378412, percent error 40.30
# Epoch    14, train loss 0.353193, train error 12.65,  val loss 1.373295, percent error 36.00
# Epoch    15, train loss 0.311650, train error 12.10,  val loss 1.433554, percent error 38.60
# Epoch    16, train loss 0.314574, train error 11.95,  val loss 1.660084, percent error 40.20
# Epoch    17, train loss 0.304121, train error 10.70,  val loss 1.577331, percent error 42.00
# Epoch    18, train loss 0.360880, train error 12.93,  val loss 1.616569, percent error 36.90
# Epoch    19, train loss 0.318569, train error 10.55,  val loss 1.632765, percent error 37.00
# Epoch    20, train loss 0.085526, train error 2.15,  val loss 1.371020, percent error 35.60
# Epoch    21, train loss 0.046891, train error 0.78,  val loss 1.413604, percent error 33.40
# Epoch    22, train loss 0.026054, train error 0.07,  val loss 1.446444, percent error 32.90
# Epoch    23, train loss 0.017526, train error 0.03,  val loss 1.461506, percent error 33.20
# Epoch    24, train loss 0.013352, train error 0.00,  val loss 1.494654, percent error 33.60
# Epoch    25, train loss 0.010534, train error 0.00,  val loss 1.521314, percent error 33.90
# Epoch    26, train loss 0.009004, train error 0.00,  val loss 1.552313, percent error 33.40
# Epoch    27, train loss 0.008028, train error 0.00,  val loss 1.581483, percent error 33.70
# Epoch    28, train loss 0.007062, train error 0.00,  val loss 1.601041, percent error 33.80
# Epoch    29, train loss 0.006371, train error 0.00,  val loss 1.630592, percent error 33.70
# Epoch    30, train loss 0.005810, train error 0.00,  val loss 1.646002, percent error 34.00
# Epoch    31, train loss 0.005334, train error 0.00,  val loss 1.670759, percent error 33.80
# Epoch    32, train loss 0.004949, train error 0.00,  val loss 1.689782, percent error 33.50
# Epoch    33, train loss 0.004589, train error 0.00,  val loss 1.707732, percent error 33.50
# Epoch    34, train loss 0.004260, train error 0.00,  val loss 1.721589, percent error 33.80
# Epoch    35, train loss 0.003991, train error 0.00,  val loss 1.732778, percent error 33.60
# Epoch    36, train loss 0.003762, train error 0.00,  val loss 1.752895, percent error 33.80
# Epoch    37, train loss 0.003559, train error 0.00,  val loss 1.762595, percent error 33.60
# Epoch    38, train loss 0.003363, train error 0.00,  val loss 1.777586, percent error 33.40
# Epoch    39, train loss 0.003198, train error 0.00,  val loss 1.788464, percent error 33.70
# Epoch    40, train loss 0.003106, train error 0.00,  val loss 1.794186, percent error 33.60
# Epoch    41, train loss 0.003033, train error 0.00,  val loss 1.798831, percent error 33.80
# Epoch    42, train loss 0.002962, train error 0.00,  val loss 1.806187, percent error 34.00
# Epoch    43, train loss 0.002894, train error 0.00,  val loss 1.811768, percent error 33.60
# Epoch    44, train loss 0.002830, train error 0.00,  val loss 1.816632, percent error 33.80
# Epoch    45, train loss 0.002770, train error 0.00,  val loss 1.822691, percent error 33.80
# Epoch    46, train loss 0.002710, train error 0.00,  val loss 1.828083, percent error 33.70
# Epoch    47, train loss 0.002653, train error 0.00,  val loss 1.832135, percent error 33.70
# Epoch    48, train loss 0.002598, train error 0.00,  val loss 1.838069, percent error 33.70
# Epoch    49, train loss 0.002546, train error 0.00,  val loss 1.843542, percent error 33.90
# Epoch    50, train loss 0.002495, train error 0.00,  val loss 1.848216, percent error 33.80
# Epoch    51, train loss 0.002446, train error 0.00,  val loss 1.852952, percent error 33.70
# Epoch    52, train loss 0.002401, train error 0.00,  val loss 1.856456, percent error 33.80
# Epoch    53, train loss 0.002354, train error 0.00,  val loss 1.862229, percent error 33.90
# Epoch    54, train loss 0.002310, train error 0.00,  val loss 1.866538, percent error 33.90
# Epoch    55, train loss 0.002268, train error 0.00,  val loss 1.871388, percent error 33.90
# Epoch    56, train loss 0.002227, train error 0.00,  val loss 1.875486, percent error 33.90
# Epoch    57, train loss 0.002189, train error 0.00,  val loss 1.879949, percent error 33.80
# Epoch    58, train loss 0.002150, train error 0.00,  val loss 1.884999, percent error 33.70
# Epoch    59, train loss 0.002114, train error 0.00,  val loss 1.888470, percent error 33.90
# Epoch    60, train loss 0.002095, train error 0.00,  val loss 1.890510, percent error 33.80
# Epoch    61, train loss 0.002077, train error 0.00,  val loss 1.893048, percent error 33.90
# Epoch    62, train loss 0.002060, train error 0.00,  val loss 1.894745, percent error 33.90
# Epoch    63, train loss 0.002043, train error 0.00,  val loss 1.896314, percent error 33.90
# Epoch    64, train loss 0.002026, train error 0.00,  val loss 1.899095, percent error 34.00
# Epoch    65, train loss 0.002010, train error 0.00,  val loss 1.900821, percent error 33.90
# Epoch    66, train loss 0.001994, train error 0.00,  val loss 1.902929, percent error 34.00
# Epoch    67, train loss 0.001978, train error 0.00,  val loss 1.904834, percent error 33.90
# Epoch    68, train loss 0.001962, train error 0.00,  val loss 1.907128, percent error 33.90
# Epoch    69, train loss 0.001946, train error 0.00,  val loss 1.908710, percent error 33.90
# Epoch    70, train loss 0.001931, train error 0.00,  val loss 1.910663, percent error 33.90
# Epoch    71, train loss 0.001916, train error 0.00,  val loss 1.912815, percent error 33.90
# Epoch    72, train loss 0.001901, train error 0.00,  val loss 1.914697, percent error 33.90
# Epoch    73, train loss 0.001887, train error 0.00,  val loss 1.916352, percent error 33.90
# Epoch    74, train loss 0.001872, train error 0.00,  val loss 1.918314, percent error 33.90
# Epoch    75, train loss 0.001858, train error 0.00,  val loss 1.920472, percent error 33.90
# Epoch    76, train loss 0.001844, train error 0.00,  val loss 1.921880, percent error 33.90
# Epoch    77, train loss 0.001830, train error 0.00,  val loss 1.923975, percent error 33.70
# Epoch    78, train loss 0.001817, train error 0.00,  val loss 1.925853, percent error 33.80
# Epoch    79, train loss 0.001803, train error 0.00,  val loss 1.927978, percent error 33.90
# Epoch    80, train loss 0.001797, train error 0.00,  val loss 1.928808, percent error 33.90
# Epoch    81, train loss 0.001790, train error 0.00,  val loss 1.929561, percent error 33.80
# Epoch    82, train loss 0.001783, train error 0.00,  val loss 1.930674, percent error 33.80
# Epoch    83, train loss 0.001777, train error 0.00,  val loss 1.931224, percent error 33.80
# Epoch    84, train loss 0.001770, train error 0.00,  val loss 1.932334, percent error 33.80
# Epoch    85, train loss 0.001764, train error 0.00,  val loss 1.933267, percent error 33.80
# Epoch    86, train loss 0.001758, train error 0.00,  val loss 1.933985, percent error 33.80
# Epoch    87, train loss 0.001751, train error 0.00,  val loss 1.935079, percent error 33.80
# Epoch    88, train loss 0.001745, train error 0.00,  val loss 1.936010, percent error 33.80
# Epoch    89, train loss 0.001739, train error 0.00,  val loss 1.936761, percent error 33.80
# Epoch    90, train loss 0.001733, train error 0.00,  val loss 1.937681, percent error 33.80
# Epoch    91, train loss 0.001726, train error 0.00,  val loss 1.938453, percent error 33.80
# Epoch    92, train loss 0.001720, train error 0.00,  val loss 1.939443, percent error 33.80
# Epoch    93, train loss 0.001714, train error 0.00,  val loss 1.940307, percent error 33.80
# Epoch    94, train loss 0.001708, train error 0.00,  val loss 1.941388, percent error 33.80
# Epoch    95, train loss 0.001702, train error 0.00,  val loss 1.942138, percent error 33.80
# Epoch    96, train loss 0.001696, train error 0.00,  val loss 1.942903, percent error 33.80
# Epoch    97, train loss 0.001690, train error 0.00,  val loss 1.944065, percent error 33.80
# Epoch    98, train loss 0.001685, train error 0.00,  val loss 1.944746, percent error 33.80
# Epoch    99, train loss 0.001679, train error 0.00,  val loss 1.945448, percent error 33.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
