# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-1khv2ltr
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-1khv2ltr
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (3.9.0)
# Requirement already satisfied: scipy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 4000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.


model = nn.Sequential(
    nn.Conv1d(1, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10),
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')
  # for name, param in model.named_parameters():
  #   if param.requires_grad:
  #       print(f"Layer: {name}")
  #       print(f"Shape: {param.shape}\n")
  # # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 0.608348, train error 21.95,  val loss 0.680676, percent error 23.45
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch     1, train loss 0.200238, train error 7.55,  val loss 0.331928, percent error 10.97
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch     2, train loss 0.129279, train error 4.07,  val loss 0.321973, percent error 10.32
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch     3, train loss 0.104016, train error 3.35,  val loss 0.321629, percent error 9.22
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch     4, train loss 0.080516, train error 2.75,  val loss 0.315594, percent error 8.88
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch     5, train loss 0.087050, train error 2.75,  val loss 0.310848, percent error 8.82
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch     6, train loss 0.096073, train error 3.57,  val loss 0.369141, percent error 10.20
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch     7, train loss 0.059930, train error 2.10,  val loss 0.301870, percent error 8.43
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch     8, train loss 0.055834, train error 1.85,  val loss 0.323491, percent error 8.50
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch     9, train loss 0.053451, train error 1.72,  val loss 0.328755, percent error 8.55
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    10, train loss 0.083230, train error 2.53,  val loss 0.354782, percent error 9.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    11, train loss 0.052134, train error 1.78,  val loss 0.360732, percent error 9.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    12, train loss 0.105399, train error 3.72,  val loss 0.468254, percent error 11.20
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    13, train loss 0.038298, train error 1.10,  val loss 0.317558, percent error 8.50
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    14, train loss 0.031653, train error 0.93,  val loss 0.345138, percent error 8.70
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    15, train loss 0.031165, train error 0.88,  val loss 0.356672, percent error 8.28
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    16, train loss 0.033797, train error 0.95,  val loss 0.347512, percent error 8.50
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    17, train loss 0.069670, train error 2.15,  val loss 0.415242, percent error 9.65
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    18, train loss 0.094966, train error 2.72,  val loss 0.402712, percent error 8.82
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    19, train loss 0.072705, train error 2.65,  val loss 0.451937, percent error 9.25
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    20, train loss 0.021351, train error 0.65,  val loss 0.371303, percent error 8.62
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    21, train loss 0.011240, train error 0.18,  val loss 0.342334, percent error 7.95
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    22, train loss 0.009290, train error 0.10,  val loss 0.349430, percent error 8.15
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    23, train loss 0.009025, train error 0.07,  val loss 0.358826, percent error 8.28
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    24, train loss 0.007961, train error 0.07,  val loss 0.355252, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    25, train loss 0.007713, train error 0.03,  val loss 0.354272, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    26, train loss 0.007154, train error 0.05,  val loss 0.368641, percent error 8.20
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    27, train loss 0.006209, train error 0.05,  val loss 0.363565, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    28, train loss 0.005861, train error 0.03,  val loss 0.367889, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    29, train loss 0.005325, train error 0.00,  val loss 0.370015, percent error 7.90
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    30, train loss 0.005245, train error 0.00,  val loss 0.378393, percent error 8.22
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    31, train loss 0.005061, train error 0.00,  val loss 0.375718, percent error 7.97
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    32, train loss 0.004765, train error 0.00,  val loss 0.379496, percent error 8.15
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    33, train loss 0.004795, train error 0.00,  val loss 0.382479, percent error 8.20
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    34, train loss 0.004591, train error 0.00,  val loss 0.383980, percent error 7.95
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    35, train loss 0.004463, train error 0.00,  val loss 0.379559, percent error 7.82
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    36, train loss 0.004095, train error 0.00,  val loss 0.390632, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    37, train loss 0.003942, train error 0.00,  val loss 0.393984, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    38, train loss 0.004707, train error 0.00,  val loss 0.400425, percent error 8.30
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    39, train loss 0.003689, train error 0.00,  val loss 0.395021, percent error 8.05
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    40, train loss 0.003570, train error 0.00,  val loss 0.395292, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    41, train loss 0.003512, train error 0.00,  val loss 0.394188, percent error 8.03
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    42, train loss 0.003465, train error 0.00,  val loss 0.396711, percent error 8.18
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    43, train loss 0.003414, train error 0.00,  val loss 0.396864, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    44, train loss 0.003364, train error 0.00,  val loss 0.398196, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    45, train loss 0.003315, train error 0.00,  val loss 0.398669, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    46, train loss 0.003282, train error 0.00,  val loss 0.399529, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    47, train loss 0.003233, train error 0.00,  val loss 0.401386, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    48, train loss 0.003199, train error 0.00,  val loss 0.402019, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    49, train loss 0.003146, train error 0.00,  val loss 0.401042, percent error 8.05
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    50, train loss 0.003116, train error 0.00,  val loss 0.402931, percent error 8.03
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    51, train loss 0.003086, train error 0.00,  val loss 0.402869, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    52, train loss 0.003047, train error 0.00,  val loss 0.405405, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    53, train loss 0.003004, train error 0.00,  val loss 0.406065, percent error 8.03
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    54, train loss 0.002964, train error 0.00,  val loss 0.406223, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    55, train loss 0.002941, train error 0.00,  val loss 0.408103, percent error 7.95
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    56, train loss 0.002907, train error 0.00,  val loss 0.407626, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    57, train loss 0.002866, train error 0.00,  val loss 0.408282, percent error 7.95
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    58, train loss 0.002835, train error 0.00,  val loss 0.409642, percent error 8.03
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    59, train loss 0.002805, train error 0.00,  val loss 0.409731, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    60, train loss 0.002786, train error 0.00,  val loss 0.410989, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    61, train loss 0.002771, train error 0.00,  val loss 0.411492, percent error 7.97
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    62, train loss 0.002754, train error 0.00,  val loss 0.411580, percent error 8.00
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    63, train loss 0.002740, train error 0.00,  val loss 0.411686, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    64, train loss 0.002729, train error 0.00,  val loss 0.412858, percent error 8.05
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    65, train loss 0.002711, train error 0.00,  val loss 0.412703, percent error 8.05
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    66, train loss 0.002698, train error 0.00,  val loss 0.413439, percent error 8.05
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    67, train loss 0.002685, train error 0.00,  val loss 0.413430, percent error 8.05
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    68, train loss 0.002673, train error 0.00,  val loss 0.413692, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    69, train loss 0.002657, train error 0.00,  val loss 0.414388, percent error 8.03
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    70, train loss 0.002645, train error 0.00,  val loss 0.414883, percent error 8.05
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    71, train loss 0.002634, train error 0.00,  val loss 0.415221, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    72, train loss 0.002626, train error 0.00,  val loss 0.414895, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    73, train loss 0.002607, train error 0.00,  val loss 0.415176, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    74, train loss 0.002594, train error 0.00,  val loss 0.416034, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    75, train loss 0.002581, train error 0.00,  val loss 0.416587, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    76, train loss 0.002567, train error 0.00,  val loss 0.416775, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    77, train loss 0.002557, train error 0.00,  val loss 0.417131, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    78, train loss 0.002543, train error 0.00,  val loss 0.417583, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    79, train loss 0.002530, train error 0.00,  val loss 0.417887, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    80, train loss 0.002524, train error 0.00,  val loss 0.418004, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    81, train loss 0.002518, train error 0.00,  val loss 0.418107, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    82, train loss 0.002511, train error 0.00,  val loss 0.418120, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    83, train loss 0.002505, train error 0.00,  val loss 0.418329, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    84, train loss 0.002500, train error 0.00,  val loss 0.418270, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    85, train loss 0.002495, train error 0.00,  val loss 0.419181, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    86, train loss 0.002488, train error 0.00,  val loss 0.419175, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    87, train loss 0.002483, train error 0.00,  val loss 0.419647, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    88, train loss 0.002476, train error 0.00,  val loss 0.419155, percent error 8.12
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    89, train loss 0.002471, train error 0.00,  val loss 0.419409, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    90, train loss 0.002465, train error 0.00,  val loss 0.419559, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    91, train loss 0.002459, train error 0.00,  val loss 0.419619, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    92, train loss 0.002454, train error 0.00,  val loss 0.419825, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    93, train loss 0.002448, train error 0.00,  val loss 0.420209, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    94, train loss 0.002442, train error 0.00,  val loss 0.420091, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    95, train loss 0.002437, train error 0.00,  val loss 0.420552, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    96, train loss 0.002431, train error 0.00,  val loss 0.420679, percent error 8.07
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    97, train loss 0.002426, train error 0.00,  val loss 0.421177, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    98, train loss 0.002420, train error 0.00,  val loss 0.420937, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
#
# Epoch    99, train loss 0.002415, train error 0.00,  val loss 0.421157, percent error 8.10
# Layer: 0.weight
# Shape: torch.Size([15, 1, 3])
#
# Layer: 0.bias
# Shape: torch.Size([15])
#
# Layer: 2.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 2.bias
# Shape: torch.Size([15])
#
# Layer: 4.weight
# Shape: torch.Size([15, 15, 3])
#
# Layer: 4.bias
# Shape: torch.Size([15])
#
# Layer: 7.weight
# Shape: torch.Size([10, 60])
#
# Layer: 7.bias
# Shape: torch.Size([10])
