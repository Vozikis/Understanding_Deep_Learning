# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-1khv2ltr
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-1khv2ltr
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (3.9.0)
# Requirement already satisfied: scipy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 4000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.


model = nn.Sequential(
    nn.Conv1d(1, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10),
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')
  # for name, param in model.named_parameters():
  #   if param.requires_grad:
  #       print(f"Layer: {name}")
  #       print(f"Shape: {param.shape}\n")
  # # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 0.639413, train error 23.50,  val loss 0.697865, percent error 25.65
# Epoch     1, train loss 0.259116, train error 9.55,  val loss 0.391050, percent error 13.35
# Epoch     2, train loss 0.170018, train error 6.07,  val loss 0.354314, percent error 10.72
# Epoch     3, train loss 0.177739, train error 6.15,  val loss 0.390711, percent error 10.90
# Epoch     4, train loss 0.089430, train error 2.80,  val loss 0.320801, percent error 9.53
# Epoch     5, train loss 0.057789, train error 1.62,  val loss 0.319056, percent error 8.60
# Epoch     6, train loss 0.069037, train error 2.32,  val loss 0.339994, percent error 9.05
# Epoch     7, train loss 0.082379, train error 2.70,  val loss 0.352106, percent error 8.78
# Epoch     8, train loss 0.060732, train error 2.07,  val loss 0.332464, percent error 8.70
# Epoch     9, train loss 0.066848, train error 2.53,  val loss 0.328234, percent error 8.32
# Epoch    10, train loss 0.057788, train error 1.82,  val loss 0.354606, percent error 8.40
# Epoch    11, train loss 0.049026, train error 1.53,  val loss 0.333999, percent error 8.68
# Epoch    12, train loss 0.044810, train error 1.32,  val loss 0.328365, percent error 8.03
# Epoch    13, train loss 0.039142, train error 1.35,  val loss 0.358614, percent error 8.30
# Epoch    14, train loss 0.053549, train error 1.95,  val loss 0.353770, percent error 8.60
# Epoch    15, train loss 0.055772, train error 1.80,  val loss 0.407899, percent error 8.72
# Epoch    16, train loss 0.074931, train error 2.50,  val loss 0.430214, percent error 9.07
# Epoch    17, train loss 0.058477, train error 2.15,  val loss 0.391365, percent error 9.18
# Epoch    18, train loss 0.044668, train error 1.47,  val loss 0.397879, percent error 8.47
# Epoch    19, train loss 0.103243, train error 2.93,  val loss 0.408580, percent error 9.10
# Epoch    20, train loss 0.022202, train error 0.53,  val loss 0.334748, percent error 8.00
# Epoch    21, train loss 0.013379, train error 0.22,  val loss 0.332490, percent error 7.65
# Epoch    22, train loss 0.010902, train error 0.22,  val loss 0.344258, percent error 7.53
# Epoch    23, train loss 0.009115, train error 0.10,  val loss 0.348316, percent error 7.53
# Epoch    24, train loss 0.007532, train error 0.10,  val loss 0.351938, percent error 7.55
# Epoch    25, train loss 0.006918, train error 0.03,  val loss 0.355355, percent error 7.60
# Epoch    26, train loss 0.006605, train error 0.00,  val loss 0.356155, percent error 7.68
# Epoch    27, train loss 0.006005, train error 0.00,  val loss 0.362574, percent error 7.72
# Epoch    28, train loss 0.005713, train error 0.00,  val loss 0.368227, percent error 7.78
# Epoch    29, train loss 0.005623, train error 0.00,  val loss 0.370485, percent error 7.90
# Epoch    30, train loss 0.005193, train error 0.00,  val loss 0.371984, percent error 7.80
# Epoch    31, train loss 0.004867, train error 0.00,  val loss 0.375471, percent error 7.82
# Epoch    32, train loss 0.004763, train error 0.00,  val loss 0.375413, percent error 7.75
# Epoch    33, train loss 0.004516, train error 0.00,  val loss 0.383250, percent error 7.75
# Epoch    34, train loss 0.004337, train error 0.00,  val loss 0.380714, percent error 7.85
# Epoch    35, train loss 0.004159, train error 0.00,  val loss 0.386196, percent error 8.00
# Epoch    36, train loss 0.003946, train error 0.00,  val loss 0.384918, percent error 7.90
# Epoch    37, train loss 0.003894, train error 0.00,  val loss 0.389715, percent error 7.95
# Epoch    38, train loss 0.003813, train error 0.00,  val loss 0.393001, percent error 7.88
# Epoch    39, train loss 0.003688, train error 0.00,  val loss 0.394464, percent error 7.88
# Epoch    40, train loss 0.003489, train error 0.00,  val loss 0.394561, percent error 7.97
# Epoch    41, train loss 0.003431, train error 0.00,  val loss 0.394525, percent error 7.93
# Epoch    42, train loss 0.003366, train error 0.00,  val loss 0.394870, percent error 8.03
# Epoch    43, train loss 0.003310, train error 0.00,  val loss 0.397175, percent error 8.00
# Epoch    44, train loss 0.003259, train error 0.00,  val loss 0.397110, percent error 8.03
# Epoch    45, train loss 0.003231, train error 0.00,  val loss 0.400045, percent error 7.97
# Epoch    46, train loss 0.003189, train error 0.00,  val loss 0.398992, percent error 8.07
# Epoch    47, train loss 0.003132, train error 0.00,  val loss 0.399729, percent error 7.97
# Epoch    48, train loss 0.003092, train error 0.00,  val loss 0.400942, percent error 8.05
# Epoch    49, train loss 0.003062, train error 0.00,  val loss 0.401200, percent error 8.03
# Epoch    50, train loss 0.003039, train error 0.00,  val loss 0.404855, percent error 7.95
# Epoch    51, train loss 0.002968, train error 0.00,  val loss 0.403979, percent error 8.05
# Epoch    52, train loss 0.002933, train error 0.00,  val loss 0.404438, percent error 7.95
# Epoch    53, train loss 0.002894, train error 0.00,  val loss 0.405019, percent error 8.03
# Epoch    54, train loss 0.002865, train error 0.00,  val loss 0.408280, percent error 8.05
# Epoch    55, train loss 0.002830, train error 0.00,  val loss 0.406988, percent error 8.00
# Epoch    56, train loss 0.002807, train error 0.00,  val loss 0.410855, percent error 8.03
# Epoch    57, train loss 0.002752, train error 0.00,  val loss 0.409286, percent error 8.03
# Epoch    58, train loss 0.002717, train error 0.00,  val loss 0.410015, percent error 8.05
# Epoch    59, train loss 0.002685, train error 0.00,  val loss 0.411483, percent error 8.05
# Epoch    60, train loss 0.002664, train error 0.00,  val loss 0.412554, percent error 8.05
# Epoch    61, train loss 0.002648, train error 0.00,  val loss 0.412312, percent error 8.07
# Epoch    62, train loss 0.002632, train error 0.00,  val loss 0.413024, percent error 8.07
# Epoch    63, train loss 0.002615, train error 0.00,  val loss 0.413353, percent error 8.10
# Epoch    64, train loss 0.002598, train error 0.00,  val loss 0.413809, percent error 8.07
# Epoch    65, train loss 0.002583, train error 0.00,  val loss 0.413750, percent error 8.07
# Epoch    66, train loss 0.002569, train error 0.00,  val loss 0.414439, percent error 8.07
# Epoch    67, train loss 0.002554, train error 0.00,  val loss 0.414694, percent error 8.10
# Epoch    68, train loss 0.002541, train error 0.00,  val loss 0.414969, percent error 8.07
# Epoch    69, train loss 0.002525, train error 0.00,  val loss 0.415549, percent error 8.10
# Epoch    70, train loss 0.002511, train error 0.00,  val loss 0.416245, percent error 8.10
# Epoch    71, train loss 0.002496, train error 0.00,  val loss 0.416638, percent error 8.10
# Epoch    72, train loss 0.002484, train error 0.00,  val loss 0.417073, percent error 8.07
# Epoch    73, train loss 0.002468, train error 0.00,  val loss 0.416755, percent error 8.10
# Epoch    74, train loss 0.002455, train error 0.00,  val loss 0.417522, percent error 8.12
# Epoch    75, train loss 0.002441, train error 0.00,  val loss 0.418399, percent error 8.10
# Epoch    76, train loss 0.002427, train error 0.00,  val loss 0.418511, percent error 8.10
# Epoch    77, train loss 0.002416, train error 0.00,  val loss 0.419271, percent error 8.15
# Epoch    78, train loss 0.002402, train error 0.00,  val loss 0.419436, percent error 8.12
# Epoch    79, train loss 0.002388, train error 0.00,  val loss 0.419605, percent error 8.15
# Epoch    80, train loss 0.002381, train error 0.00,  val loss 0.419895, percent error 8.12
# Epoch    81, train loss 0.002374, train error 0.00,  val loss 0.419888, percent error 8.15
# Epoch    82, train loss 0.002368, train error 0.00,  val loss 0.420105, percent error 8.12
# Epoch    83, train loss 0.002362, train error 0.00,  val loss 0.420414, percent error 8.15
# Epoch    84, train loss 0.002355, train error 0.00,  val loss 0.420552, percent error 8.15
# Epoch    85, train loss 0.002349, train error 0.00,  val loss 0.420920, percent error 8.12
# Epoch    86, train loss 0.002342, train error 0.00,  val loss 0.420826, percent error 8.15
# Epoch    87, train loss 0.002337, train error 0.00,  val loss 0.420953, percent error 8.15
# Epoch    88, train loss 0.002330, train error 0.00,  val loss 0.421238, percent error 8.18
# Epoch    89, train loss 0.002324, train error 0.00,  val loss 0.421630, percent error 8.12
# Epoch    90, train loss 0.002318, train error 0.00,  val loss 0.421793, percent error 8.12
# Epoch    91, train loss 0.002313, train error 0.00,  val loss 0.421817, percent error 8.18
# Epoch    92, train loss 0.002306, train error 0.00,  val loss 0.421972, percent error 8.18
# Epoch    93, train loss 0.002300, train error 0.00,  val loss 0.422374, percent error 8.18
# Epoch    94, train loss 0.002294, train error 0.00,  val loss 0.422405, percent error 8.18
# Epoch    95, train loss 0.002289, train error 0.00,  val loss 0.422564, percent error 8.18
# Epoch    96, train loss 0.002282, train error 0.00,  val loss 0.422743, percent error 8.18
# Epoch    97, train loss 0.002277, train error 0.00,  val loss 0.423026, percent error 8.20
# Epoch    98, train loss 0.002271, train error 0.00,  val loss 0.423066, percent error 8.18
# Epoch    99, train loss 0.002265, train error 0.00,  val loss 0.423279, percent error 8.18
