# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-rwfwt0f3
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-rwfwt0f3
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (3.9.0)
# Requirement already satisfied: scipy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 4000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
class ResidualNetwork(torch.nn.Module):
    def __init__(self, input_size, output_size, hidden_size=100):
        super(ResidualNetwork, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, hidden_size)
        self.linear4 = nn.Linear(hidden_size, output_size)
        print("Initialized MLPBase model with {} parameters".format(self.count_params()))

    def count_params(self):
        return sum([p.view(-1).shape[0] for p in self.parameters()])

    def forward(self, x):
        # Input layer
        h1 = self.linear1(x).relu()
        
        # First residual block
        h2 = self.linear2(h1).relu()
        h2 = h2 + h1  # Adding the residual connection

        # Second residual block
        h3 = self.linear3(h2).relu()
        h3 = h3 + h2  # Adding the residual connection

        # Output layer
        return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.755450, train error 67.32,  val loss 1.818362, percent error 71.20
# Epoch     1, train loss 1.466559, train error 55.25,  val loss 1.590974, percent error 62.92
# Epoch     2, train loss 1.279982, train error 46.67,  val loss 1.429031, percent error 54.28
# Epoch     3, train loss 1.109516, train error 38.65,  val loss 1.315096, percent error 49.08
# Epoch     4, train loss 0.981013, train error 34.80,  val loss 1.219435, percent error 45.70
# Epoch     5, train loss 0.886379, train error 31.68,  val loss 1.169005, percent error 43.80
# Epoch     6, train loss 0.815268, train error 30.22,  val loss 1.142171, percent error 42.40
# Epoch     7, train loss 0.738001, train error 26.93,  val loss 1.110478, percent error 41.20
# Epoch     8, train loss 0.687939, train error 24.65,  val loss 1.114364, percent error 41.12
# Epoch     9, train loss 0.651779, train error 23.30,  val loss 1.159302, percent error 42.80
# Epoch    10, train loss 0.614875, train error 22.00,  val loss 1.140791, percent error 41.45
# Epoch    11, train loss 0.565089, train error 20.10,  val loss 1.120999, percent error 40.80
# Epoch    12, train loss 0.513996, train error 17.57,  val loss 1.156833, percent error 40.30
# Epoch    13, train loss 0.466886, train error 16.40,  val loss 1.151500, percent error 40.03
# Epoch    14, train loss 0.448459, train error 15.60,  val loss 1.206326, percent error 39.85
# Epoch    15, train loss 0.426253, train error 15.72,  val loss 1.274892, percent error 40.42
# Epoch    16, train loss 0.431784, train error 15.47,  val loss 1.312832, percent error 40.45
# Epoch    17, train loss 0.337453, train error 11.60,  val loss 1.244035, percent error 39.65
# Epoch    18, train loss 0.286878, train error 9.32,  val loss 1.256665, percent error 38.88
# Epoch    19, train loss 0.297740, train error 10.35,  val loss 1.345035, percent error 39.67
# Epoch    20, train loss 0.182787, train error 4.22,  val loss 1.283102, percent error 38.03
# Epoch    21, train loss 0.160084, train error 3.03,  val loss 1.335482, percent error 39.03
# Epoch    22, train loss 0.138243, train error 2.38,  val loss 1.339634, percent error 38.28
# Epoch    23, train loss 0.122782, train error 1.97,  val loss 1.372327, percent error 38.08
# Epoch    24, train loss 0.112530, train error 1.50,  val loss 1.394417, percent error 38.20
# Epoch    25, train loss 0.096533, train error 1.05,  val loss 1.437717, percent error 37.80
# Epoch    26, train loss 0.086703, train error 0.72,  val loss 1.455951, percent error 37.65
# Epoch    27, train loss 0.076898, train error 0.50,  val loss 1.494495, percent error 38.03
# Epoch    28, train loss 0.072650, train error 0.47,  val loss 1.533533, percent error 37.60
# Epoch    29, train loss 0.062788, train error 0.38,  val loss 1.546168, percent error 37.22
# Epoch    30, train loss 0.058355, train error 0.38,  val loss 1.582541, percent error 37.97
# Epoch    31, train loss 0.051540, train error 0.15,  val loss 1.608565, percent error 37.45
# Epoch    32, train loss 0.044142, train error 0.03,  val loss 1.626386, percent error 37.50
# Epoch    33, train loss 0.040209, train error 0.05,  val loss 1.653590, percent error 37.28
# Epoch    34, train loss 0.037059, train error 0.03,  val loss 1.693511, percent error 37.20
# Epoch    35, train loss 0.033157, train error 0.03,  val loss 1.713616, percent error 37.50
# Epoch    36, train loss 0.031364, train error 0.00,  val loss 1.740632, percent error 37.40
# Epoch    37, train loss 0.028421, train error 0.00,  val loss 1.764012, percent error 37.38
# Epoch    38, train loss 0.026463, train error 0.00,  val loss 1.783111, percent error 37.25
# Epoch    39, train loss 0.024505, train error 0.00,  val loss 1.804230, percent error 37.33
# Epoch    40, train loss 0.022417, train error 0.00,  val loss 1.816069, percent error 37.28
# Epoch    41, train loss 0.021589, train error 0.00,  val loss 1.829514, percent error 37.20
# Epoch    42, train loss 0.020868, train error 0.00,  val loss 1.839055, percent error 37.28
# Epoch    43, train loss 0.020229, train error 0.00,  val loss 1.853485, percent error 37.17
# Epoch    44, train loss 0.019708, train error 0.00,  val loss 1.860370, percent error 37.08
# Epoch    45, train loss 0.019166, train error 0.00,  val loss 1.868200, percent error 37.12
# Epoch    46, train loss 0.018538, train error 0.00,  val loss 1.878009, percent error 37.10
# Epoch    47, train loss 0.018201, train error 0.00,  val loss 1.890240, percent error 37.22
# Epoch    48, train loss 0.017580, train error 0.00,  val loss 1.897815, percent error 37.28
# Epoch    49, train loss 0.017162, train error 0.00,  val loss 1.904732, percent error 37.15
# Epoch    50, train loss 0.016639, train error 0.00,  val loss 1.912974, percent error 37.17
# Epoch    51, train loss 0.016185, train error 0.00,  val loss 1.923125, percent error 37.15
# Epoch    52, train loss 0.015740, train error 0.00,  val loss 1.930981, percent error 37.22
# Epoch    53, train loss 0.015385, train error 0.00,  val loss 1.940531, percent error 37.20
# Epoch    54, train loss 0.015002, train error 0.00,  val loss 1.949188, percent error 37.28
# Epoch    55, train loss 0.014662, train error 0.00,  val loss 1.953534, percent error 37.17
# Epoch    56, train loss 0.014351, train error 0.00,  val loss 1.961815, percent error 37.10
# Epoch    57, train loss 0.014036, train error 0.00,  val loss 1.970477, percent error 37.22
# Epoch    58, train loss 0.013751, train error 0.00,  val loss 1.975368, percent error 37.12
# Epoch    59, train loss 0.013340, train error 0.00,  val loss 1.985080, percent error 37.12
# Epoch    60, train loss 0.013138, train error 0.00,  val loss 1.990021, percent error 37.20
# Epoch    61, train loss 0.012985, train error 0.00,  val loss 1.991775, percent error 37.17
# Epoch    62, train loss 0.012850, train error 0.00,  val loss 1.996018, percent error 37.25
# Epoch    63, train loss 0.012713, train error 0.00,  val loss 2.000276, percent error 37.25
# Epoch    64, train loss 0.012568, train error 0.00,  val loss 2.004158, percent error 37.25
# Epoch    65, train loss 0.012435, train error 0.00,  val loss 2.007251, percent error 37.22
# Epoch    66, train loss 0.012312, train error 0.00,  val loss 2.011036, percent error 37.22
# Epoch    67, train loss 0.012182, train error 0.00,  val loss 2.014756, percent error 37.20
# Epoch    68, train loss 0.012051, train error 0.00,  val loss 2.017457, percent error 37.20
# Epoch    69, train loss 0.011931, train error 0.00,  val loss 2.020648, percent error 37.17
# Epoch    70, train loss 0.011807, train error 0.00,  val loss 2.023854, percent error 37.20
# Epoch    71, train loss 0.011693, train error 0.00,  val loss 2.027999, percent error 37.15
# Epoch    72, train loss 0.011571, train error 0.00,  val loss 2.030712, percent error 37.12
# Epoch    73, train loss 0.011457, train error 0.00,  val loss 2.033837, percent error 37.25
# Epoch    74, train loss 0.011344, train error 0.00,  val loss 2.038537, percent error 37.12
# Epoch    75, train loss 0.011234, train error 0.00,  val loss 2.040774, percent error 37.05
# Epoch    76, train loss 0.011121, train error 0.00,  val loss 2.044027, percent error 37.17
# Epoch    77, train loss 0.011010, train error 0.00,  val loss 2.047259, percent error 37.12
# Epoch    78, train loss 0.010903, train error 0.00,  val loss 2.050031, percent error 37.10
# Epoch    79, train loss 0.010810, train error 0.00,  val loss 2.053674, percent error 37.12
# Epoch    80, train loss 0.010745, train error 0.00,  val loss 2.054757, percent error 37.05
# Epoch    81, train loss 0.010692, train error 0.00,  val loss 2.056839, percent error 37.08
# Epoch    82, train loss 0.010642, train error 0.00,  val loss 2.057511, percent error 37.03
# Epoch    83, train loss 0.010592, train error 0.00,  val loss 2.059791, percent error 37.08
# Epoch    84, train loss 0.010542, train error 0.00,  val loss 2.061373, percent error 37.05
# Epoch    85, train loss 0.010492, train error 0.00,  val loss 2.062730, percent error 37.08
# Epoch    86, train loss 0.010445, train error 0.00,  val loss 2.064267, percent error 37.08
# Epoch    87, train loss 0.010396, train error 0.00,  val loss 2.065534, percent error 37.03
# Epoch    88, train loss 0.010348, train error 0.00,  val loss 2.068093, percent error 37.10
# Epoch    89, train loss 0.010302, train error 0.00,  val loss 2.068939, percent error 37.05
# Epoch    90, train loss 0.010255, train error 0.00,  val loss 2.070454, percent error 37.03
# Epoch    91, train loss 0.010210, train error 0.00,  val loss 2.071498, percent error 37.08
# Epoch    92, train loss 0.010162, train error 0.00,  val loss 2.073572, percent error 37.00
# Epoch    93, train loss 0.010116, train error 0.00,  val loss 2.074406, percent error 37.03
# Epoch    94, train loss 0.010070, train error 0.00,  val loss 2.076189, percent error 37.05
# Epoch    95, train loss 0.010026, train error 0.00,  val loss 2.078078, percent error 37.00
# Epoch    96, train loss 0.009981, train error 0.00,  val loss 2.079460, percent error 37.05
# Epoch    97, train loss 0.009936, train error 0.00,  val loss 2.080536, percent error 37.05
# Epoch    98, train loss 0.009893, train error 0.00,  val loss 2.082580, percent error 36.97
# Epoch    99, train loss 0.009849, train error 0.00,  val loss 2.084129, percent error 37.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
