# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-wonhk7ic
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-wonhk7ic
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (3.9.0)
# Requirement already satisfied: scipy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302473, train error 89.72,  test loss 2.302690, test error 90.30
# Epoch   100, train loss 2.302357, train error 89.65,  test loss 2.302953, test error 89.88
# Epoch   200, train loss 2.302350, train error 89.65,  test loss 2.302954, test error 89.88
# Epoch   300, train loss 2.302355, train error 89.65,  test loss 2.303007, test error 89.88
# Epoch   400, train loss 2.302361, train error 89.65,  test loss 2.302981, test error 89.88
# Epoch   500, train loss 2.302356, train error 89.72,  test loss 2.302932, test error 90.30
# Epoch   600, train loss 2.302355, train error 89.65,  test loss 2.302950, test error 89.88
# Epoch   700, train loss 2.302356, train error 89.65,  test loss 2.303012, test error 89.88
# Epoch   800, train loss 2.302358, train error 89.72,  test loss 2.303042, test error 90.30
# Epoch   900, train loss 2.302354, train error 89.65,  test loss 2.302940, test error 89.88
# Training model with   4 hidden variables
# Epoch     0, train loss 2.264955, train error 84.68,  test loss 2.257907, test error 83.35
# Epoch   100, train loss 1.740200, train error 64.03,  test loss 1.569459, test error 61.03
# Epoch   200, train loss 1.718658, train error 63.33,  test loss 1.575318, test error 60.67
# Epoch   300, train loss 1.715541, train error 63.03,  test loss 1.590703, test error 60.83
# Epoch   400, train loss 1.707757, train error 62.40,  test loss 1.572191, test error 60.78
# Epoch   500, train loss 1.713999, train error 63.22,  test loss 1.569315, test error 60.60
# Epoch   600, train loss 1.705614, train error 62.62,  test loss 1.577693, test error 60.85
# Epoch   700, train loss 1.705350, train error 62.67,  test loss 1.575667, test error 61.12
# Epoch   800, train loss 1.704526, train error 62.60,  test loss 1.575672, test error 61.05
# Epoch   900, train loss 1.706124, train error 62.50,  test loss 1.582733, test error 60.95
# Training model with   6 hidden variables
# Epoch     0, train loss 2.303128, train error 89.80,  test loss 2.303207, test error 90.30
# Epoch   100, train loss 1.703373, train error 62.10,  test loss 1.561987, test error 60.67
# Epoch   200, train loss 1.636313, train error 59.05,  test loss 1.469249, test error 56.00
# Epoch   300, train loss 1.594145, train error 56.72,  test loss 1.435480, test error 54.10
# Epoch   400, train loss 1.585415, train error 56.38,  test loss 1.436454, test error 54.10
# Epoch   500, train loss 1.580650, train error 56.12,  test loss 1.431210, test error 54.08
# Epoch   600, train loss 1.582514, train error 55.97,  test loss 1.436142, test error 54.15
# Epoch   700, train loss 1.578448, train error 55.75,  test loss 1.435889, test error 54.33
# Epoch   800, train loss 1.577433, train error 56.17,  test loss 1.436320, test error 54.30
# Epoch   900, train loss 1.570648, train error 55.75,  test loss 1.423713, test error 53.75
# Training model with   8 hidden variables
# Epoch     0, train loss 2.204267, train error 80.43,  test loss 2.181278, test error 78.95
# Epoch   100, train loss 1.605377, train error 56.62,  test loss 1.447596, test error 54.53
# Epoch   200, train loss 1.574613, train error 56.05,  test loss 1.431730, test error 54.58
# Epoch   300, train loss 1.551635, train error 54.85,  test loss 1.430948, test error 55.08
# Epoch   400, train loss 1.534687, train error 54.53,  test loss 1.439704, test error 55.40
# Epoch   500, train loss 1.518386, train error 54.30,  test loss 1.430518, test error 54.95
# Epoch   600, train loss 1.513181, train error 53.97,  test loss 1.432186, test error 54.58
# Epoch   700, train loss 1.504484, train error 54.05,  test loss 1.437554, test error 54.83
# Epoch   800, train loss 1.503106, train error 54.35,  test loss 1.464716, test error 54.53
# Epoch   900, train loss 1.492787, train error 53.83,  test loss 1.455652, test error 53.88
# Training model with  10 hidden variables
# Epoch     0, train loss 2.303556, train error 86.47,  test loss 2.298549, test error 86.45
# Epoch   100, train loss 1.507003, train error 51.38,  test loss 1.350626, test error 51.00
# Epoch   200, train loss 1.452271, train error 49.35,  test loss 1.317568, test error 48.97
# Epoch   300, train loss 1.420234, train error 47.45,  test loss 1.317170, test error 49.08
# Epoch   400, train loss 1.414411, train error 47.47,  test loss 1.327715, test error 49.22
# Epoch   500, train loss 1.405983, train error 46.88,  test loss 1.320822, test error 48.60
# Epoch   600, train loss 1.400018, train error 46.90,  test loss 1.325001, test error 48.30
# Epoch   700, train loss 1.396945, train error 46.38,  test loss 1.327652, test error 48.62
# Epoch   800, train loss 1.394178, train error 47.00,  test loss 1.328479, test error 48.67
# Epoch   900, train loss 1.386098, train error 46.38,  test loss 1.329282, test error 48.45
# Training model with  14 hidden variables
# Epoch     0, train loss 2.192704, train error 80.65,  test loss 2.165527, test error 81.32
# Epoch   100, train loss 1.397437, train error 47.03,  test loss 1.281107, test error 47.20
# Epoch   200, train loss 1.338108, train error 45.33,  test loss 1.272517, test error 47.20
# Epoch   300, train loss 1.317147, train error 44.33,  test loss 1.298328, test error 47.78
# Epoch   400, train loss 1.303715, train error 43.95,  test loss 1.322865, test error 48.38
# Epoch   500, train loss 1.287732, train error 43.28,  test loss 1.338784, test error 49.28
# Epoch   600, train loss 1.278174, train error 43.92,  test loss 1.361189, test error 48.70
# Epoch   700, train loss 1.264761, train error 43.05,  test loss 1.375229, test error 48.60
# Epoch   800, train loss 1.264639, train error 43.67,  test loss 1.427041, test error 49.62
# Epoch   900, train loss 1.254980, train error 42.47,  test loss 1.434840, test error 49.60
# Training model with  18 hidden variables
# Epoch     0, train loss 2.270216, train error 84.68,  test loss 2.259513, test error 84.65
# Epoch   100, train loss 1.327310, train error 43.80,  test loss 1.259240, test error 46.70
# Epoch   200, train loss 1.235819, train error 41.72,  test loss 1.292641, test error 48.38
# Epoch   300, train loss 1.186248, train error 39.62,  test loss 1.317942, test error 47.17
# Epoch   400, train loss 1.158414, train error 38.50,  test loss 1.357166, test error 48.33
# Epoch   500, train loss 1.136826, train error 38.25,  test loss 1.392741, test error 48.25
# Epoch   600, train loss 1.128220, train error 37.92,  test loss 1.433702, test error 49.70
# Epoch   700, train loss 1.119440, train error 37.72,  test loss 1.457774, test error 49.62
# Epoch   800, train loss 1.109499, train error 37.35,  test loss 1.484059, test error 49.45
# Epoch   900, train loss 1.102201, train error 37.28,  test loss 1.497688, test error 50.20
# Training model with  22 hidden variables
# Epoch     0, train loss 2.144937, train error 80.03,  test loss 2.105949, test error 79.00
# Epoch   100, train loss 1.311231, train error 44.35,  test loss 1.367184, test error 51.08
# Epoch   200, train loss 1.167506, train error 38.75,  test loss 1.417663, test error 50.90
# Epoch   300, train loss 1.122780, train error 38.53,  test loss 1.508903, test error 52.53
# Epoch   400, train loss 1.076520, train error 36.97,  test loss 1.599654, test error 53.85
# Epoch   500, train loss 1.045522, train error 36.03,  test loss 1.680633, test error 54.75
# Epoch   600, train loss 1.021615, train error 34.65,  test loss 1.743830, test error 54.00
# Epoch   700, train loss 1.013949, train error 35.47,  test loss 1.793835, test error 54.67
# Epoch   800, train loss 0.996956, train error 34.82,  test loss 1.824253, test error 53.83
# Epoch   900, train loss 0.992195, train error 34.43,  test loss 1.900671, test error 55.00
# Training model with  26 hidden variables
# Epoch     0, train loss 2.155155, train error 79.60,  test loss 2.152640, test error 80.60
# Epoch   100, train loss 1.188928, train error 39.42,  test loss 1.323773, test error 49.62
# Epoch   200, train loss 1.042219, train error 35.00,  test loss 1.447127, test error 50.65
# Epoch   300, train loss 0.973028, train error 33.00,  test loss 1.596695, test error 52.17
# Epoch   400, train loss 0.944165, train error 32.22,  test loss 1.732443, test error 53.12
# Epoch   500, train loss 0.910560, train error 30.80,  test loss 1.826517, test error 52.90
# Epoch   600, train loss 0.863045, train error 29.12,  test loss 1.920533, test error 53.15
# Epoch   700, train loss 0.859648, train error 28.93,  test loss 2.029331, test error 53.88
# Epoch   800, train loss 0.834516, train error 27.72,  test loss 2.120295, test error 54.15
# Epoch   900, train loss 0.850016, train error 29.22,  test loss 2.213273, test error 54.70
# Training model with  30 hidden variables
# Epoch     0, train loss 2.195721, train error 81.20,  test loss 2.165013, test error 79.95
# Epoch   100, train loss 1.102249, train error 36.12,  test loss 1.327777, test error 48.03
# Epoch   200, train loss 0.906477, train error 29.68,  test loss 1.462451, test error 48.97
# Epoch   300, train loss 0.845053, train error 27.65,  test loss 1.640028, test error 50.53
# Epoch   400, train loss 0.764108, train error 25.53,  test loss 1.814079, test error 51.58
# Epoch   500, train loss 0.722103, train error 23.72,  test loss 1.970564, test error 52.22
# Epoch   600, train loss 0.713612, train error 24.05,  test loss 2.087555, test error 52.03
# Epoch   700, train loss 0.673375, train error 22.90,  test loss 2.225614, test error 52.97
# Epoch   800, train loss 0.656009, train error 22.05,  test loss 2.350326, test error 53.28
# Epoch   900, train loss 0.675769, train error 23.25,  test loss 2.437930, test error 53.10
# Training model with  35 hidden variables
# Epoch     0, train loss 2.117552, train error 79.07,  test loss 2.088431, test error 78.05
# Epoch   100, train loss 1.000410, train error 33.03,  test loss 1.370629, test error 48.30
# Epoch   200, train loss 0.826182, train error 27.85,  test loss 1.647195, test error 50.25
# Epoch   300, train loss 0.682581, train error 23.18,  test loss 1.964737, test error 52.08
# Epoch   400, train loss 0.616760, train error 21.68,  test loss 2.276105, test error 53.42
# Epoch   500, train loss 0.585686, train error 20.25,  test loss 2.538596, test error 53.00
# Epoch   600, train loss 0.525173, train error 17.55,  test loss 2.806131, test error 53.53
# Epoch   700, train loss 0.517392, train error 18.32,  test loss 3.128925, test error 54.92
# Epoch   800, train loss 0.521825, train error 18.68,  test loss 3.376765, test error 54.70
# Epoch   900, train loss 0.491569, train error 17.50,  test loss 3.656065, test error 55.55
# Training model with  40 hidden variables
# Epoch     0, train loss 2.124905, train error 79.90,  test loss 2.096235, test error 79.20
# Epoch   100, train loss 0.862623, train error 27.70,  test loss 1.386142, test error 47.40
# Epoch   200, train loss 0.606631, train error 19.38,  test loss 1.901318, test error 50.12
# Epoch   300, train loss 0.472123, train error 15.50,  test loss 2.521380, test error 52.40
# Epoch   400, train loss 0.400453, train error 14.03,  test loss 3.235683, test error 53.67
# Epoch   500, train loss 0.350425, train error 12.68,  test loss 3.890687, test error 54.72
# Epoch   600, train loss 0.304230, train error 10.05,  test loss 4.720861, test error 55.65
# Epoch   700, train loss 0.290638, train error 9.85,  test loss 5.352532, test error 55.03
# Epoch   800, train loss 0.256347, train error 8.78,  test loss 6.014560, test error 54.70
# Epoch   900, train loss 0.262198, train error 9.78,  test loss 6.763003, test error 55.95
# Training model with  45 hidden variables
# Epoch     0, train loss 2.100246, train error 78.10,  test loss 2.061932, test error 78.12
# Epoch   100, train loss 0.812687, train error 25.10,  test loss 1.491564, test error 50.42
# Epoch   200, train loss 0.533540, train error 17.50,  test loss 2.212573, test error 53.25
# Epoch   300, train loss 0.360042, train error 11.38,  test loss 3.103990, test error 54.62
# Epoch   400, train loss 0.279614, train error 9.60,  test loss 4.149261, test error 54.33
# Epoch   500, train loss 0.171726, train error 5.55,  test loss 5.321128, test error 56.08
# Epoch   600, train loss 0.194617, train error 6.95,  test loss 6.400160, test error 55.90
# Epoch   700, train loss 0.217745, train error 8.03,  test loss 7.588405, test error 56.12
# Epoch   800, train loss 0.341706, train error 11.55,  test loss 8.625148, test error 57.67
# Epoch   900, train loss 0.111709, train error 4.30,  test loss 9.209932, test error 55.88
# Training model with  50 hidden variables
# Epoch     0, train loss 2.064720, train error 77.38,  test loss 2.004365, test error 76.03
# Epoch   100, train loss 0.719449, train error 22.45,  test loss 1.609322, test error 51.70
# Epoch   200, train loss 0.314039, train error 8.22,  test loss 2.661920, test error 54.80
# Epoch   300, train loss 0.132167, train error 2.53,  test loss 4.253635, test error 56.70
# Epoch   400, train loss 0.031441, train error 0.03,  test loss 5.698843, test error 56.90
# Epoch   500, train loss 0.014496, train error 0.00,  test loss 6.641274, test error 57.03
# Epoch   600, train loss 0.009192, train error 0.00,  test loss 7.292961, test error 57.45
# Epoch   700, train loss 0.006515, train error 0.00,  test loss 7.754131, test error 57.22
# Epoch   800, train loss 0.005028, train error 0.00,  test loss 8.132257, test error 57.42
# Epoch   900, train loss 0.004050, train error 0.00,  test loss 8.448972, test error 57.53
# Training model with  55 hidden variables
# Epoch     0, train loss 2.091082, train error 77.00,  test loss 2.050812, test error 77.60
# Epoch   100, train loss 0.661282, train error 19.88,  test loss 1.621855, test error 50.95
# Epoch   200, train loss 0.247893, train error 5.68,  test loss 2.889995, test error 55.28
# Epoch   300, train loss 0.049283, train error 0.03,  test loss 4.595370, test error 55.38
# Epoch   400, train loss 0.016487, train error 0.00,  test loss 5.773350, test error 56.05
# Epoch   500, train loss 0.009286, train error 0.00,  test loss 6.434951, test error 56.22
# Epoch   600, train loss 0.006273, train error 0.00,  test loss 6.924718, test error 56.22
# Epoch   700, train loss 0.004675, train error 0.00,  test loss 7.295137, test error 56.53
# Epoch   800, train loss 0.003667, train error 0.00,  test loss 7.591621, test error 56.55
# Epoch   900, train loss 0.003015, train error 0.00,  test loss 7.847923, test error 56.47
# Training model with  60 hidden variables
# Epoch     0, train loss 2.053583, train error 76.47,  test loss 2.007453, test error 77.05
# Epoch   100, train loss 0.543181, train error 16.30,  test loss 1.734926, test error 50.55
# Epoch   200, train loss 0.112712, train error 1.20,  test loss 3.398868, test error 53.00
# Epoch   300, train loss 0.019351, train error 0.00,  test loss 4.718591, test error 52.92
# Epoch   400, train loss 0.009402, train error 0.00,  test loss 5.402194, test error 52.90
# Epoch   500, train loss 0.005989, train error 0.00,  test loss 5.848939, test error 53.17
# Epoch   600, train loss 0.004260, train error 0.00,  test loss 6.177886, test error 53.30
# Epoch   700, train loss 0.003269, train error 0.00,  test loss 6.439606, test error 53.22
# Epoch   800, train loss 0.002627, train error 0.00,  test loss 6.659447, test error 53.40
# Epoch   900, train loss 0.002187, train error 0.00,  test loss 6.844872, test error 53.42
# Training model with  70 hidden variables
# Epoch     0, train loss 2.019088, train error 76.00,  test loss 1.955059, test error 75.72
# Epoch   100, train loss 0.351695, train error 9.00,  test loss 1.986489, test error 52.95
# Epoch   200, train loss 0.031505, train error 0.03,  test loss 3.527807, test error 52.92
# Epoch   300, train loss 0.010704, train error 0.00,  test loss 4.295138, test error 53.28
# Epoch   400, train loss 0.006095, train error 0.00,  test loss 4.721017, test error 53.10
# Epoch   500, train loss 0.004059, train error 0.00,  test loss 5.023223, test error 53.08
# Epoch   600, train loss 0.003021, train error 0.00,  test loss 5.254333, test error 53.08
# Epoch   700, train loss 0.002369, train error 0.00,  test loss 5.435818, test error 53.10
# Epoch   800, train loss 0.001935, train error 0.00,  test loss 5.593002, test error 53.05
# Epoch   900, train loss 0.001630, train error 0.00,  test loss 5.725488, test error 52.92
# Training model with  80 hidden variables
# Epoch     0, train loss 2.022526, train error 75.80,  test loss 1.972862, test error 76.07
# Epoch   100, train loss 0.221190, train error 3.93,  test loss 2.136197, test error 50.83
# Epoch   200, train loss 0.018942, train error 0.00,  test loss 3.463907, test error 53.00
# Epoch   300, train loss 0.007757, train error 0.00,  test loss 4.026004, test error 53.25
# Epoch   400, train loss 0.004626, train error 0.00,  test loss 4.351636, test error 53.22
# Epoch   500, train loss 0.003213, train error 0.00,  test loss 4.584661, test error 53.42
# Epoch   600, train loss 0.002415, train error 0.00,  test loss 4.767253, test error 53.42
# Epoch   700, train loss 0.001922, train error 0.00,  test loss 4.913527, test error 53.45
# Epoch   800, train loss 0.001582, train error 0.00,  test loss 5.038988, test error 53.42
# Epoch   900, train loss 0.001340, train error 0.00,  test loss 5.148455, test error 53.53
# Training model with  90 hidden variables
# Epoch     0, train loss 2.006288, train error 74.40,  test loss 1.919906, test error 75.05
# Epoch   100, train loss 0.147488, train error 1.05,  test loss 2.191759, test error 52.05
# Epoch   200, train loss 0.015353, train error 0.00,  test loss 3.246100, test error 52.92
# Epoch   300, train loss 0.006713, train error 0.00,  test loss 3.690799, test error 52.70
# Epoch   400, train loss 0.004079, train error 0.00,  test loss 3.957939, test error 52.88
# Epoch   500, train loss 0.002857, train error 0.00,  test loss 4.150154, test error 53.00
# Epoch   600, train loss 0.002169, train error 0.00,  test loss 4.300550, test error 53.15
# Epoch   700, train loss 0.001732, train error 0.00,  test loss 4.425082, test error 53.12
# Epoch   800, train loss 0.001433, train error 0.00,  test loss 4.530237, test error 53.22
# Epoch   900, train loss 0.001217, train error 0.00,  test loss 4.621730, test error 53.17
# Training model with 100 hidden variables
# Epoch     0, train loss 1.992919, train error 73.82,  test loss 1.903046, test error 73.78
# Epoch   100, train loss 0.112167, train error 0.50,  test loss 2.217675, test error 52.28
# Epoch   200, train loss 0.012781, train error 0.00,  test loss 3.066446, test error 52.22
# Epoch   300, train loss 0.005838, train error 0.00,  test loss 3.432031, test error 52.70
# Epoch   400, train loss 0.003614, train error 0.00,  test loss 3.654978, test error 52.62
# Epoch   500, train loss 0.002567, train error 0.00,  test loss 3.823646, test error 52.58
# Epoch   600, train loss 0.001961, train error 0.00,  test loss 3.952883, test error 52.78
# Epoch   700, train loss 0.001573, train error 0.00,  test loss 4.058843, test error 52.65
# Epoch   800, train loss 0.001304, train error 0.00,  test loss 4.150081, test error 52.60
# Epoch   900, train loss 0.001110, train error 0.00,  test loss 4.228169, test error 52.72
# Training model with 120 hidden variables
# Epoch     0, train loss 1.959223, train error 72.93,  test loss 1.881647, test error 73.65
# Epoch   100, train loss 0.046769, train error 0.00,  test loss 2.248271, test error 51.08
# Epoch   200, train loss 0.009105, train error 0.00,  test loss 2.810684, test error 50.83
# Epoch   300, train loss 0.004568, train error 0.00,  test loss 3.079512, test error 50.97
# Epoch   400, train loss 0.002937, train error 0.00,  test loss 3.253407, test error 50.80
# Epoch   500, train loss 0.002122, train error 0.00,  test loss 3.379483, test error 50.78
# Epoch   600, train loss 0.001643, train error 0.00,  test loss 3.481549, test error 50.83
# Epoch   700, train loss 0.001331, train error 0.00,  test loss 3.565931, test error 50.88
# Epoch   800, train loss 0.001112, train error 0.00,  test loss 3.638832, test error 50.85
# Epoch   900, train loss 0.000951, train error 0.00,  test loss 3.701762, test error 50.83
# Training model with 140 hidden variables
# Epoch     0, train loss 1.962144, train error 72.62,  test loss 1.884300, test error 72.97
# Epoch   100, train loss 0.034921, train error 0.00,  test loss 2.142064, test error 48.67
# Epoch   200, train loss 0.007912, train error 0.00,  test loss 2.613051, test error 48.88
# Epoch   300, train loss 0.004060, train error 0.00,  test loss 2.832684, test error 48.72
# Epoch   400, train loss 0.002643, train error 0.00,  test loss 2.981179, test error 48.62
# Epoch   500, train loss 0.001925, train error 0.00,  test loss 3.090782, test error 48.80
# Epoch   600, train loss 0.001497, train error 0.00,  test loss 3.178653, test error 48.92
# Epoch   700, train loss 0.001216, train error 0.00,  test loss 3.250125, test error 48.85
# Epoch   800, train loss 0.001019, train error 0.00,  test loss 3.312614, test error 48.72
# Epoch   900, train loss 0.000873, train error 0.00,  test loss 3.366506, test error 48.83
# Training model with 160 hidden variables
# Epoch     0, train loss 1.935538, train error 70.55,  test loss 1.888348, test error 72.70
# Epoch   100, train loss 0.029269, train error 0.00,  test loss 2.036397, test error 47.92
# Epoch   200, train loss 0.007225, train error 0.00,  test loss 2.427576, test error 47.75
# Epoch   300, train loss 0.003777, train error 0.00,  test loss 2.620055, test error 47.90
# Epoch   400, train loss 0.002478, train error 0.00,  test loss 2.748274, test error 47.90
# Epoch   500, train loss 0.001811, train error 0.00,  test loss 2.844464, test error 47.75
# Epoch   600, train loss 0.001413, train error 0.00,  test loss 2.921296, test error 47.67
# Epoch   700, train loss 0.001150, train error 0.00,  test loss 2.985315, test error 47.72
# Epoch   800, train loss 0.000965, train error 0.00,  test loss 3.040061, test error 47.70
# Epoch   900, train loss 0.000828, train error 0.00,  test loss 3.087535, test error 47.70
# Training model with 180 hidden variables
# Epoch     0, train loss 1.919138, train error 70.30,  test loss 1.851215, test error 72.85
# Epoch   100, train loss 0.024324, train error 0.00,  test loss 2.007647, test error 48.03
# Epoch   200, train loss 0.006585, train error 0.00,  test loss 2.348756, test error 47.80
# Epoch   300, train loss 0.003497, train error 0.00,  test loss 2.517217, test error 47.85
# Epoch   400, train loss 0.002316, train error 0.00,  test loss 2.631695, test error 47.58
# Epoch   500, train loss 0.001702, train error 0.00,  test loss 2.716525, test error 47.70
# Epoch   600, train loss 0.001333, train error 0.00,  test loss 2.785079, test error 47.88
# Epoch   700, train loss 0.001088, train error 0.00,  test loss 2.841451, test error 47.65
# Epoch   800, train loss 0.000915, train error 0.00,  test loss 2.890486, test error 47.60
# Epoch   900, train loss 0.000786, train error 0.00,  test loss 2.933246, test error 47.62
# Training model with 200 hidden variables
# Epoch     0, train loss 1.921485, train error 70.12,  test loss 1.842009, test error 72.10
# Epoch   100, train loss 0.021065, train error 0.00,  test loss 2.023556, test error 47.58
# Epoch   200, train loss 0.006053, train error 0.00,  test loss 2.350127, test error 47.90
# Epoch   300, train loss 0.003288, train error 0.00,  test loss 2.516199, test error 47.70
# Epoch   400, train loss 0.002192, train error 0.00,  test loss 2.628239, test error 47.67
# Epoch   500, train loss 0.001620, train error 0.00,  test loss 2.712575, test error 47.83
# Epoch   600, train loss 0.001273, train error 0.00,  test loss 2.780783, test error 47.85
# Epoch   700, train loss 0.001041, train error 0.00,  test loss 2.837843, test error 47.90
# Epoch   800, train loss 0.000877, train error 0.00,  test loss 2.886535, test error 47.97
# Epoch   900, train loss 0.000755, train error 0.00,  test loss 2.929574, test error 48.05
# Training model with 250 hidden variables
# Epoch     0, train loss 1.912688, train error 69.25,  test loss 1.827518, test error 69.70
# Epoch   100, train loss 0.017398, train error 0.00,  test loss 1.861237, test error 46.88
# Epoch   200, train loss 0.005469, train error 0.00,  test loss 2.100914, test error 47.03
# Epoch   300, train loss 0.003034, train error 0.00,  test loss 2.231154, test error 46.85
# Epoch   400, train loss 0.002047, train error 0.00,  test loss 2.319961, test error 47.08
# Epoch   500, train loss 0.001523, train error 0.00,  test loss 2.387180, test error 47.17
# Epoch   600, train loss 0.001202, train error 0.00,  test loss 2.441576, test error 47.10
# Epoch   700, train loss 0.000987, train error 0.00,  test loss 2.487051, test error 47.22
# Epoch   800, train loss 0.000833, train error 0.00,  test loss 2.526162, test error 47.15
# Epoch   900, train loss 0.000719, train error 0.00,  test loss 2.560150, test error 47.08
# Training model with 300 hidden variables
# Epoch     0, train loss 1.944204, train error 71.10,  test loss 1.845465, test error 70.47
# Epoch   100, train loss 0.014821, train error 0.00,  test loss 1.909396, test error 47.55
# Epoch   200, train loss 0.004890, train error 0.00,  test loss 2.136375, test error 47.62
# Epoch   300, train loss 0.002767, train error 0.00,  test loss 2.261048, test error 47.50
# Epoch   400, train loss 0.001882, train error 0.00,  test loss 2.345533, test error 47.50
# Epoch   500, train loss 0.001407, train error 0.00,  test loss 2.411304, test error 47.47
# Epoch   600, train loss 0.001114, train error 0.00,  test loss 2.463518, test error 47.60
# Epoch   700, train loss 0.000917, train error 0.00,  test loss 2.506974, test error 47.60
# Epoch   800, train loss 0.000776, train error 0.00,  test loss 2.545067, test error 47.50
# Epoch   900, train loss 0.000670, train error 0.00,  test loss 2.578101, test error 47.50
# Training model with 400 hidden variables
# Epoch     0, train loss 1.883407, train error 67.53,  test loss 1.813360, test error 69.53
# Epoch   100, train loss 0.011634, train error 0.00,  test loss 1.816448, test error 46.60
# Epoch   200, train loss 0.004157, train error 0.00,  test loss 1.999390, test error 46.28
# Epoch   300, train loss 0.002405, train error 0.00,  test loss 2.101150, test error 46.33
# Epoch   400, train loss 0.001656, train error 0.00,  test loss 2.172031, test error 46.30
# Epoch   500, train loss 0.001248, train error 0.00,  test loss 2.226035, test error 46.22
# Epoch   600, train loss 0.000993, train error 0.00,  test loss 2.270739, test error 46.15
# Epoch   700, train loss 0.000820, train error 0.00,  test loss 2.307634, test error 46.10
# Epoch   800, train loss 0.000696, train error 0.00,  test loss 2.340295, test error 46.00
# Epoch   900, train loss 0.000603, train error 0.00,  test loss 2.368378, test error 46.05

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
