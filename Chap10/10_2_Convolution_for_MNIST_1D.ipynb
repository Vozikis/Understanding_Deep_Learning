# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-ul702opa
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-ul702opa
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (3.9.0)
# Requirement already satisfied: scipy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(1, 15, 3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(15, 15, 3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(15, 15, 3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.887705, train error 74.80,  val loss 1.887954, percent error 74.20
# Epoch     1, train loss 1.527554, train error 60.90,  val loss 1.543887, percent error 64.70
# Epoch     2, train loss 1.319322, train error 54.83,  val loss 1.337976, percent error 56.50
# Epoch     3, train loss 1.422567, train error 56.25,  val loss 1.472421, percent error 60.30
# Epoch     4, train loss 1.254050, train error 51.35,  val loss 1.277639, percent error 52.90
# Epoch     5, train loss 1.163852, train error 48.60,  val loss 1.188998, percent error 49.60
# Epoch     6, train loss 1.084791, train error 44.92,  val loss 1.132007, percent error 48.30
# Epoch     7, train loss 0.973248, train error 39.75,  val loss 1.005511, percent error 42.40
# Epoch     8, train loss 0.907211, train error 36.58,  val loss 0.945185, percent error 39.90
# Epoch     9, train loss 0.903778, train error 35.55,  val loss 0.975866, percent error 40.30
# Epoch    10, train loss 0.739116, train error 28.32,  val loss 0.798341, percent error 32.20
# Epoch    11, train loss 0.703470, train error 26.35,  val loss 0.775303, percent error 30.40
# Epoch    12, train loss 0.604047, train error 23.50,  val loss 0.679161, percent error 26.80
# Epoch    13, train loss 0.635080, train error 24.05,  val loss 0.732448, percent error 28.10
# Epoch    14, train loss 0.527716, train error 19.72,  val loss 0.608115, percent error 23.60
# Epoch    15, train loss 0.502719, train error 18.62,  val loss 0.624616, percent error 24.00
# Epoch    16, train loss 0.469503, train error 17.60,  val loss 0.579766, percent error 21.80
# Epoch    17, train loss 0.404238, train error 15.45,  val loss 0.513751, percent error 20.10
# Epoch    18, train loss 0.376911, train error 13.88,  val loss 0.505093, percent error 19.30
# Epoch    19, train loss 0.364562, train error 13.53,  val loss 0.465579, percent error 16.90
# Epoch    20, train loss 0.292377, train error 10.38,  val loss 0.434782, percent error 15.20
# Epoch    21, train loss 0.272936, train error 9.55,  val loss 0.405394, percent error 14.20
# Epoch    22, train loss 0.294297, train error 10.97,  val loss 0.431785, percent error 15.50
# Epoch    23, train loss 0.240998, train error 8.85,  val loss 0.370600, percent error 13.40
# Epoch    24, train loss 0.227580, train error 8.22,  val loss 0.383332, percent error 13.20
# Epoch    25, train loss 0.237392, train error 8.57,  val loss 0.354199, percent error 11.90
# Epoch    26, train loss 0.236410, train error 8.00,  val loss 0.409104, percent error 14.20
# Epoch    27, train loss 0.200170, train error 6.68,  val loss 0.366081, percent error 12.10
# Epoch    28, train loss 0.192737, train error 6.53,  val loss 0.371783, percent error 12.10
# Epoch    29, train loss 0.177857, train error 5.90,  val loss 0.340634, percent error 10.60
# Epoch    30, train loss 0.175755, train error 6.25,  val loss 0.347150, percent error 11.30
# Epoch    31, train loss 0.167868, train error 5.65,  val loss 0.345161, percent error 11.10
# Epoch    32, train loss 0.172097, train error 5.75,  val loss 0.377791, percent error 12.00
# Epoch    33, train loss 0.155609, train error 5.05,  val loss 0.344137, percent error 11.70
# Epoch    34, train loss 0.144732, train error 5.00,  val loss 0.341555, percent error 10.00
# Epoch    35, train loss 0.150622, train error 5.28,  val loss 0.350256, percent error 10.40
# Epoch    36, train loss 0.131127, train error 4.68,  val loss 0.314328, percent error 10.00
# Epoch    37, train loss 0.139767, train error 4.20,  val loss 0.328748, percent error 10.60
# Epoch    38, train loss 0.151091, train error 5.20,  val loss 0.356088, percent error 10.90
# Epoch    39, train loss 0.112398, train error 3.55,  val loss 0.305215, percent error 10.00
# Epoch    40, train loss 0.096752, train error 2.97,  val loss 0.310791, percent error 9.20
# Epoch    41, train loss 0.096725, train error 3.03,  val loss 0.297878, percent error 8.80
# Epoch    42, train loss 0.092906, train error 2.72,  val loss 0.313860, percent error 9.60
# Epoch    43, train loss 0.087409, train error 2.43,  val loss 0.313472, percent error 9.30
# Epoch    44, train loss 0.093954, train error 2.85,  val loss 0.305857, percent error 9.30
# Epoch    45, train loss 0.078171, train error 2.18,  val loss 0.309675, percent error 9.10
# Epoch    46, train loss 0.076975, train error 1.75,  val loss 0.317190, percent error 9.00
# Epoch    47, train loss 0.081428, train error 2.22,  val loss 0.324927, percent error 9.60
# Epoch    48, train loss 0.079109, train error 2.25,  val loss 0.321583, percent error 8.50
# Epoch    49, train loss 0.071942, train error 1.65,  val loss 0.314275, percent error 9.70
# Epoch    50, train loss 0.077637, train error 2.10,  val loss 0.316285, percent error 9.30
# Epoch    51, train loss 0.072075, train error 1.85,  val loss 0.346008, percent error 9.60
# Epoch    52, train loss 0.081985, train error 2.75,  val loss 0.327598, percent error 10.00
# Epoch    53, train loss 0.068493, train error 1.65,  val loss 0.321107, percent error 10.10
# Epoch    54, train loss 0.064119, train error 1.47,  val loss 0.321101, percent error 9.50
# Epoch    55, train loss 0.063894, train error 1.55,  val loss 0.330464, percent error 9.30
# Epoch    56, train loss 0.059440, train error 1.10,  val loss 0.328812, percent error 9.10
# Epoch    57, train loss 0.060777, train error 1.47,  val loss 0.323423, percent error 9.00
# Epoch    58, train loss 0.057023, train error 1.15,  val loss 0.331194, percent error 9.40
# Epoch    59, train loss 0.054194, train error 1.00,  val loss 0.333712, percent error 9.30
# Epoch    60, train loss 0.052998, train error 0.90,  val loss 0.338359, percent error 9.50
# Epoch    61, train loss 0.051106, train error 0.88,  val loss 0.332326, percent error 8.70
# Epoch    62, train loss 0.049979, train error 0.70,  val loss 0.334925, percent error 9.20
# Epoch    63, train loss 0.050553, train error 0.90,  val loss 0.345574, percent error 9.50
# Epoch    64, train loss 0.050616, train error 0.80,  val loss 0.354094, percent error 9.10
# Epoch    65, train loss 0.049667, train error 0.80,  val loss 0.348002, percent error 9.60
# Epoch    66, train loss 0.048244, train error 0.72,  val loss 0.338898, percent error 9.40
# Epoch    67, train loss 0.048457, train error 0.78,  val loss 0.358055, percent error 9.00
# Epoch    68, train loss 0.048407, train error 0.85,  val loss 0.356214, percent error 9.30
# Epoch    69, train loss 0.046276, train error 0.75,  val loss 0.356895, percent error 9.40
# Epoch    70, train loss 0.047784, train error 0.78,  val loss 0.370519, percent error 9.60
# Epoch    71, train loss 0.047998, train error 0.93,  val loss 0.359257, percent error 9.40
# Epoch    72, train loss 0.044200, train error 0.72,  val loss 0.356427, percent error 9.60
# Epoch    73, train loss 0.043542, train error 0.57,  val loss 0.353762, percent error 9.30
# Epoch    74, train loss 0.045538, train error 0.72,  val loss 0.365397, percent error 9.10
# Epoch    75, train loss 0.044373, train error 0.68,  val loss 0.353836, percent error 9.80
# Epoch    76, train loss 0.042823, train error 0.62,  val loss 0.366780, percent error 9.40
# Epoch    77, train loss 0.043108, train error 0.70,  val loss 0.353635, percent error 9.60
# Epoch    78, train loss 0.041363, train error 0.55,  val loss 0.362871, percent error 9.40
# Epoch    79, train loss 0.041381, train error 0.55,  val loss 0.361521, percent error 9.40
# Epoch    80, train loss 0.039915, train error 0.55,  val loss 0.360420, percent error 9.60
# Epoch    81, train loss 0.039875, train error 0.50,  val loss 0.358148, percent error 9.40
# Epoch    82, train loss 0.039540, train error 0.53,  val loss 0.364550, percent error 9.20
# Epoch    83, train loss 0.039224, train error 0.53,  val loss 0.362550, percent error 9.80
# Epoch    84, train loss 0.039041, train error 0.50,  val loss 0.362627, percent error 9.50
# Epoch    85, train loss 0.039230, train error 0.60,  val loss 0.371678, percent error 9.30
# Epoch    86, train loss 0.038502, train error 0.45,  val loss 0.366922, percent error 9.50
# Epoch    87, train loss 0.038534, train error 0.53,  val loss 0.363489, percent error 9.20
# Epoch    88, train loss 0.038127, train error 0.55,  val loss 0.369272, percent error 9.30
# Epoch    89, train loss 0.038613, train error 0.57,  val loss 0.373019, percent error 9.20
# Epoch    90, train loss 0.038115, train error 0.55,  val loss 0.366477, percent error 9.50
# Epoch    91, train loss 0.037601, train error 0.53,  val loss 0.373000, percent error 9.80
# Epoch    92, train loss 0.037464, train error 0.47,  val loss 0.365071, percent error 9.30
# Epoch    93, train loss 0.036966, train error 0.50,  val loss 0.369428, percent error 9.60
# Epoch    94, train loss 0.037029, train error 0.50,  val loss 0.370077, percent error 9.40
# Epoch    95, train loss 0.037322, train error 0.45,  val loss 0.367818, percent error 9.50
# Epoch    96, train loss 0.036940, train error 0.43,  val loss 0.372293, percent error 9.40
# Epoch    97, train loss 0.037606, train error 0.50,  val loss 0.381154, percent error 9.40
# Epoch    98, train loss 0.036278, train error 0.50,  val loss 0.378888, percent error 9.60
# Epoch    99, train loss 0.036152, train error 0.45,  val loss 0.380032, percent error 9.40
