# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-agx_ldvb
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-agx_ldvb
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (3.9.0)
# Requirement already satisfied: scipy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_k),
                            torch.nn.ReLU(),
                            torch.nn.Linear(D_k,D_k),
                            torch.nn.ReLU(),
                            torch.nn.Linear(D_k,D_o))


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, torch.nn.Linear):
    torch.nn.init.kaiming_uniform_(layer_in.weight,  mode='fan_in', nonlinearity='relu')
    if layer_in.bias is not None:
              torch.nn.init.zeros_(layer_in.bias)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.558013, train error 60.08,  test loss 1.651145, test error 67.00
# Epoch     1, train loss 1.332378, train error 49.67,  test loss 1.438815, test error 57.90
# Epoch     2, train loss 1.128315, train error 39.90,  test loss 1.324303, test error 51.20
# Epoch     3, train loss 1.015283, train error 37.20,  test loss 1.266270, test error 49.80
# Epoch     4, train loss 0.914185, train error 32.28,  test loss 1.202417, test error 46.50
# Epoch     5, train loss 0.823582, train error 29.65,  test loss 1.170372, test error 44.50
# Epoch     6, train loss 0.714884, train error 24.38,  test loss 1.136847, test error 42.70
# Epoch     7, train loss 0.662450, train error 23.57,  test loss 1.144340, test error 43.90
# Epoch     8, train loss 0.571299, train error 19.07,  test loss 1.111417, test error 40.80
# Epoch     9, train loss 0.558690, train error 19.20,  test loss 1.173449, test error 40.70
# Epoch    10, train loss 0.430509, train error 13.25,  test loss 1.075341, test error 39.70
# Epoch    11, train loss 0.391476, train error 11.57,  test loss 1.072168, test error 37.20
# Epoch    12, train loss 0.370239, train error 10.47,  test loss 1.108971, test error 39.00
# Epoch    13, train loss 0.328820, train error 8.95,  test loss 1.109315, test error 39.80
# Epoch    14, train loss 0.302643, train error 8.07,  test loss 1.112231, test error 38.10
# Epoch    15, train loss 0.267569, train error 6.45,  test loss 1.115062, test error 38.30
# Epoch    16, train loss 0.240278, train error 5.10,  test loss 1.132370, test error 38.30
# Epoch    17, train loss 0.225193, train error 4.80,  test loss 1.164564, test error 38.00
# Epoch    18, train loss 0.209508, train error 4.35,  test loss 1.184536, test error 39.30
# Epoch    19, train loss 0.186715, train error 3.43,  test loss 1.167099, test error 37.20
# Epoch    20, train loss 0.163252, train error 2.25,  test loss 1.184556, test error 37.30
# Epoch    21, train loss 0.154338, train error 2.05,  test loss 1.203400, test error 38.30
# Epoch    22, train loss 0.145997, train error 1.60,  test loss 1.207085, test error 37.80
# Epoch    23, train loss 0.137809, train error 1.47,  test loss 1.214939, test error 37.40
# Epoch    24, train loss 0.128497, train error 1.43,  test loss 1.226308, test error 37.50
# Epoch    25, train loss 0.124619, train error 1.18,  test loss 1.235647, test error 37.20
# Epoch    26, train loss 0.119555, train error 1.07,  test loss 1.259574, test error 37.80
# Epoch    27, train loss 0.110720, train error 0.78,  test loss 1.259241, test error 38.00
# Epoch    28, train loss 0.104201, train error 0.47,  test loss 1.260416, test error 37.60
# Epoch    29, train loss 0.102832, train error 0.47,  test loss 1.302962, test error 37.20
# Epoch    30, train loss 0.094796, train error 0.30,  test loss 1.288800, test error 37.60
# Epoch    31, train loss 0.092595, train error 0.32,  test loss 1.289236, test error 37.10
# Epoch    32, train loss 0.090626, train error 0.28,  test loss 1.296339, test error 37.70
# Epoch    33, train loss 0.088405, train error 0.20,  test loss 1.298139, test error 37.40
# Epoch    34, train loss 0.087121, train error 0.20,  test loss 1.310952, test error 37.70
# Epoch    35, train loss 0.084514, train error 0.18,  test loss 1.316381, test error 37.50
# Epoch    36, train loss 0.083118, train error 0.22,  test loss 1.325543, test error 37.10
# Epoch    37, train loss 0.080084, train error 0.18,  test loss 1.329202, test error 37.10
# Epoch    38, train loss 0.078165, train error 0.12,  test loss 1.327781, test error 37.40
# Epoch    39, train loss 0.076350, train error 0.10,  test loss 1.339052, test error 37.50
# Epoch    40, train loss 0.075070, train error 0.07,  test loss 1.338653, test error 37.60
# Epoch    41, train loss 0.074189, train error 0.07,  test loss 1.343505, test error 37.40
# Epoch    42, train loss 0.073744, train error 0.15,  test loss 1.348645, test error 37.70
# Epoch    43, train loss 0.072537, train error 0.07,  test loss 1.349241, test error 37.30
# Epoch    44, train loss 0.071720, train error 0.10,  test loss 1.350208, test error 37.50
# Epoch    45, train loss 0.071141, train error 0.07,  test loss 1.353915, test error 37.40
# Epoch    46, train loss 0.070432, train error 0.10,  test loss 1.359877, test error 37.60
# Epoch    47, train loss 0.069770, train error 0.12,  test loss 1.357859, test error 37.40
# Epoch    48, train loss 0.068712, train error 0.05,  test loss 1.362950, test error 37.50
# Epoch    49, train loss 0.067884, train error 0.05,  test loss 1.365177, test error 37.30
# Epoch    50, train loss 0.067458, train error 0.03,  test loss 1.367090, test error 37.40
# Epoch    51, train loss 0.067077, train error 0.03,  test loss 1.367700, test error 37.30
# Epoch    52, train loss 0.066762, train error 0.05,  test loss 1.369076, test error 37.50
# Epoch    53, train loss 0.066373, train error 0.05,  test loss 1.372344, test error 37.50
# Epoch    54, train loss 0.066020, train error 0.05,  test loss 1.371908, test error 37.40
# Epoch    55, train loss 0.065670, train error 0.03,  test loss 1.373084, test error 37.50
# Epoch    56, train loss 0.065316, train error 0.03,  test loss 1.375068, test error 37.60
# Epoch    57, train loss 0.065021, train error 0.03,  test loss 1.375384, test error 37.70
# Epoch    58, train loss 0.064661, train error 0.03,  test loss 1.377960, test error 37.50
# Epoch    59, train loss 0.064315, train error 0.03,  test loss 1.379005, test error 37.20
# Epoch    60, train loss 0.064101, train error 0.03,  test loss 1.379624, test error 37.50
# Epoch    61, train loss 0.063929, train error 0.03,  test loss 1.380403, test error 37.40
# Epoch    62, train loss 0.063766, train error 0.03,  test loss 1.381000, test error 37.60
# Epoch    63, train loss 0.063605, train error 0.03,  test loss 1.381485, test error 37.50
# Epoch    64, train loss 0.063439, train error 0.03,  test loss 1.381642, test error 37.50
# Epoch    65, train loss 0.063271, train error 0.03,  test loss 1.382714, test error 37.70
# Epoch    66, train loss 0.063110, train error 0.03,  test loss 1.383698, test error 37.50
# Epoch    67, train loss 0.062948, train error 0.03,  test loss 1.383399, test error 37.70
# Epoch    68, train loss 0.062790, train error 0.03,  test loss 1.384935, test error 37.70
# Epoch    69, train loss 0.062624, train error 0.03,  test loss 1.385551, test error 37.50
# Epoch    70, train loss 0.062534, train error 0.03,  test loss 1.386122, test error 37.60
# Epoch    71, train loss 0.062453, train error 0.03,  test loss 1.386358, test error 37.60
# Epoch    72, train loss 0.062371, train error 0.03,  test loss 1.386579, test error 37.60
# Epoch    73, train loss 0.062291, train error 0.03,  test loss 1.386733, test error 37.60
# Epoch    74, train loss 0.062211, train error 0.03,  test loss 1.387138, test error 37.60
# Epoch    75, train loss 0.062131, train error 0.03,  test loss 1.387473, test error 37.60
# Epoch    76, train loss 0.062051, train error 0.03,  test loss 1.387668, test error 37.60
# Epoch    77, train loss 0.061970, train error 0.03,  test loss 1.388169, test error 37.60
# Epoch    78, train loss 0.061895, train error 0.03,  test loss 1.388477, test error 37.50
# Epoch    79, train loss 0.061815, train error 0.03,  test loss 1.388709, test error 37.60
# Epoch    80, train loss 0.061773, train error 0.03,  test loss 1.388795, test error 37.60
# Epoch    81, train loss 0.061733, train error 0.03,  test loss 1.389001, test error 37.60
# Epoch    82, train loss 0.061692, train error 0.03,  test loss 1.389255, test error 37.60
# Epoch    83, train loss 0.061653, train error 0.03,  test loss 1.389492, test error 37.70
# Epoch    84, train loss 0.061615, train error 0.03,  test loss 1.389502, test error 37.60
# Epoch    85, train loss 0.061574, train error 0.03,  test loss 1.389661, test error 37.60
# Epoch    86, train loss 0.061536, train error 0.03,  test loss 1.389832, test error 37.60
# Epoch    87, train loss 0.061497, train error 0.03,  test loss 1.390086, test error 37.60
# Epoch    88, train loss 0.061457, train error 0.03,  test loss 1.390232, test error 37.70
# Epoch    89, train loss 0.061419, train error 0.03,  test loss 1.390272, test error 37.60
# Epoch    90, train loss 0.061398, train error 0.03,  test loss 1.390429, test error 37.60
# Epoch    91, train loss 0.061378, train error 0.03,  test loss 1.390464, test error 37.60
# Epoch    92, train loss 0.061358, train error 0.03,  test loss 1.390521, test error 37.60
# Epoch    93, train loss 0.061339, train error 0.03,  test loss 1.390586, test error 37.60
# Epoch    94, train loss 0.061319, train error 0.03,  test loss 1.390716, test error 37.60
# Epoch    95, train loss 0.061300, train error 0.03,  test loss 1.390763, test error 37.60
# Epoch    96, train loss 0.061280, train error 0.03,  test loss 1.390869, test error 37.60
# Epoch    97, train loss 0.061261, train error 0.03,  test loss 1.390911, test error 37.60
# Epoch    98, train loss 0.061242, train error 0.03,  test loss 1.391049, test error 37.60
# Epoch    99, train loss 0.061223, train error 0.03,  test loss 1.391133, test error 37.60
# Epoch   100, train loss 0.061212, train error 0.03,  test loss 1.391201, test error 37.60
# Epoch   101, train loss 0.061202, train error 0.03,  test loss 1.391220, test error 37.60
# Epoch   102, train loss 0.061192, train error 0.03,  test loss 1.391260, test error 37.60
# Epoch   103, train loss 0.061183, train error 0.03,  test loss 1.391269, test error 37.60
# Epoch   104, train loss 0.061173, train error 0.03,  test loss 1.391333, test error 37.60
# Epoch   105, train loss 0.061164, train error 0.03,  test loss 1.391393, test error 37.60
# Epoch   106, train loss 0.061154, train error 0.03,  test loss 1.391403, test error 37.60
# Epoch   107, train loss 0.061144, train error 0.03,  test loss 1.391460, test error 37.60
# Epoch   108, train loss 0.061135, train error 0.03,  test loss 1.391511, test error 37.60
# Epoch   109, train loss 0.061125, train error 0.03,  test loss 1.391535, test error 37.60
# Epoch   110, train loss 0.061120, train error 0.03,  test loss 1.391558, test error 37.60
# Epoch   111, train loss 0.061115, train error 0.03,  test loss 1.391575, test error 37.60
# Epoch   112, train loss 0.061110, train error 0.03,  test loss 1.391625, test error 37.60
# Epoch   113, train loss 0.061105, train error 0.03,  test loss 1.391648, test error 37.60
# Epoch   114, train loss 0.061100, train error 0.03,  test loss 1.391623, test error 37.60
# Epoch   115, train loss 0.061095, train error 0.03,  test loss 1.391681, test error 37.60
# Epoch   116, train loss 0.061090, train error 0.03,  test loss 1.391693, test error 37.60
# Epoch   117, train loss 0.061086, train error 0.03,  test loss 1.391709, test error 37.60
# Epoch   118, train loss 0.061081, train error 0.03,  test loss 1.391705, test error 37.60
# Epoch   119, train loss 0.061076, train error 0.03,  test loss 1.391744, test error 37.60
# Epoch   120, train loss 0.061073, train error 0.03,  test loss 1.391763, test error 37.60
# Epoch   121, train loss 0.061071, train error 0.03,  test loss 1.391768, test error 37.60
# Epoch   122, train loss 0.061069, train error 0.03,  test loss 1.391775, test error 37.60
# Epoch   123, train loss 0.061066, train error 0.03,  test loss 1.391787, test error 37.60
# Epoch   124, train loss 0.061064, train error 0.03,  test loss 1.391794, test error 37.60
# Epoch   125, train loss 0.061061, train error 0.03,  test loss 1.391809, test error 37.60
# Epoch   126, train loss 0.061059, train error 0.03,  test loss 1.391812, test error 37.60
# Epoch   127, train loss 0.061056, train error 0.03,  test loss 1.391839, test error 37.60
# Epoch   128, train loss 0.061054, train error 0.03,  test loss 1.391831, test error 37.60
# Epoch   129, train loss 0.061052, train error 0.03,  test loss 1.391851, test error 37.60
# Epoch   130, train loss 0.061050, train error 0.03,  test loss 1.391851, test error 37.60
# Epoch   131, train loss 0.061049, train error 0.03,  test loss 1.391864, test error 37.60
# Epoch   132, train loss 0.061048, train error 0.03,  test loss 1.391864, test error 37.60
# Epoch   133, train loss 0.061047, train error 0.03,  test loss 1.391870, test error 37.60
# Epoch   134, train loss 0.061046, train error 0.03,  test loss 1.391874, test error 37.60
# Epoch   135, train loss 0.061044, train error 0.03,  test loss 1.391881, test error 37.60
# Epoch   136, train loss 0.061043, train error 0.03,  test loss 1.391880, test error 37.60
# Epoch   137, train loss 0.061042, train error 0.03,  test loss 1.391887, test error 37.60
# Epoch   138, train loss 0.061041, train error 0.03,  test loss 1.391895, test error 37.60
# Epoch   139, train loss 0.061039, train error 0.03,  test loss 1.391896, test error 37.60
# Epoch   140, train loss 0.061039, train error 0.03,  test loss 1.391899, test error 37.60
# Epoch   141, train loss 0.061038, train error 0.03,  test loss 1.391905, test error 37.60
# Epoch   142, train loss 0.061038, train error 0.03,  test loss 1.391906, test error 37.60
# Epoch   143, train loss 0.061037, train error 0.03,  test loss 1.391909, test error 37.60
# Epoch   144, train loss 0.061037, train error 0.03,  test loss 1.391913, test error 37.60
# Epoch   145, train loss 0.061036, train error 0.03,  test loss 1.391914, test error 37.60
# Epoch   146, train loss 0.061035, train error 0.03,  test loss 1.391914, test error 37.60
# Epoch   147, train loss 0.061035, train error 0.03,  test loss 1.391919, test error 37.60
# Epoch   148, train loss 0.061034, train error 0.03,  test loss 1.391922, test error 37.60
# Epoch   149, train loss 0.061034, train error 0.03,  test loss 1.391926, test error 37.60
# Epoch   150, train loss 0.061033, train error 0.03,  test loss 1.391926, test error 37.60
# Epoch   151, train loss 0.061033, train error 0.03,  test loss 1.391926, test error 37.60
# Epoch   152, train loss 0.061033, train error 0.03,  test loss 1.391928, test error 37.60
# Epoch   153, train loss 0.061033, train error 0.03,  test loss 1.391929, test error 37.60
# Epoch   154, train loss 0.061033, train error 0.03,  test loss 1.391929, test error 37.60
# Epoch   155, train loss 0.061032, train error 0.03,  test loss 1.391931, test error 37.60
# Epoch   156, train loss 0.061032, train error 0.03,  test loss 1.391931, test error 37.60
# Epoch   157, train loss 0.061032, train error 0.03,  test loss 1.391933, test error 37.60
# Epoch   158, train loss 0.061032, train error 0.03,  test loss 1.391934, test error 37.60
# Epoch   159, train loss 0.061031, train error 0.03,  test loss 1.391934, test error 37.60
# Epoch   160, train loss 0.061031, train error 0.03,  test loss 1.391934, test error 37.60
# Epoch   161, train loss 0.061031, train error 0.03,  test loss 1.391934, test error 37.60
# Epoch   162, train loss 0.061031, train error 0.03,  test loss 1.391935, test error 37.60
# Epoch   163, train loss 0.061031, train error 0.03,  test loss 1.391935, test error 37.60
# Epoch   164, train loss 0.061031, train error 0.03,  test loss 1.391936, test error 37.60
# Epoch   165, train loss 0.061031, train error 0.03,  test loss 1.391936, test error 37.60
# Epoch   166, train loss 0.061031, train error 0.03,  test loss 1.391936, test error 37.60
# Epoch   167, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   168, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   169, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   170, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   171, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   172, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   173, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   174, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   175, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   176, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   177, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   178, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   179, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   180, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   181, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   182, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   183, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   184, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   185, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   186, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   187, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   188, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   189, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   190, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   191, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   192, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   193, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   194, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   195, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   196, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   197, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   198, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   199, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   200, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   201, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   202, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   203, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   204, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   205, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   206, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   207, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   208, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   209, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   210, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   211, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   212, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   213, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   214, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   215, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   216, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   217, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   218, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   219, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   220, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   221, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   222, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   223, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   224, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   225, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   226, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   227, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   228, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   229, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   230, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   231, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   232, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   233, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   234, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   235, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   236, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   237, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   238, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   239, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   240, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   241, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   242, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   243, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   244, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   245, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   246, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   247, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   248, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   249, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   250, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   251, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   252, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   253, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   254, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   255, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   256, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   257, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   258, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   259, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   260, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   261, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   262, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   263, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   264, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   265, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   266, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   267, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   268, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   269, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   270, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   271, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   272, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   273, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   274, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   275, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   276, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   277, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   278, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   279, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   280, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   281, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   282, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   283, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   284, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   285, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   286, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   287, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   288, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   289, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   290, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   291, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   292, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   293, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   294, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   295, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   296, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   297, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   298, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   299, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   300, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   301, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   302, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   303, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   304, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   305, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   306, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   307, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   308, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   309, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   310, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   311, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   312, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   313, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   314, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   315, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   316, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   317, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   318, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   319, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   320, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   321, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   322, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   323, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   324, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   325, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   326, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   327, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   328, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   329, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   330, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   331, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   332, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   333, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   334, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   335, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   336, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   337, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   338, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   339, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   340, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   341, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   342, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   343, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   344, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   345, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   346, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   347, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   348, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   349, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   350, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   351, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   352, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   353, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   354, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   355, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   356, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   357, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   358, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   359, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   360, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   361, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   362, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   363, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   364, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   365, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   366, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   367, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   368, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   369, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   370, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   371, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   372, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   373, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   374, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   375, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   376, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   377, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   378, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   379, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   380, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   381, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   382, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   383, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   384, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   385, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   386, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   387, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   388, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   389, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   390, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   391, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   392, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   393, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   394, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   395, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   396, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   397, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   398, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   399, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   400, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   401, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   402, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   403, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   404, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   405, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   406, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   407, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   408, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   409, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   410, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   411, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   412, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   413, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   414, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   415, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   416, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   417, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   418, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   419, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   420, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   421, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   422, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   423, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   424, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   425, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   426, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   427, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   428, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   429, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   430, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   431, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   432, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   433, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   434, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   435, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   436, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   437, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   438, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   439, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   440, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   441, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   442, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   443, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   444, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   445, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   446, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   447, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60
# Epoch   448, train loss 0.061031, train error 0.03,  test loss 1.391937, test error 37.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
