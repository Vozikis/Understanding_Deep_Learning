# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-agx_ldvb
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-agx_ldvb
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (3.9.0)
# Requirement already satisfied: scipy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_k),
                            torch.nn.ReLU(),
                            torch.nn.Linear(D_k,D_k),
                            torch.nn.ReLU(),
                            torch.nn.Linear(D_k,D_o))


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, torch.nn.Linear):
    torch.nn.init.kaiming_uniform_(layer_in.weight,  mode='fan_in', nonlinearity='relu')
    if layer_in.bias is not None:
              torch.nn.init.zeros_(layer_in.bias)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.0005, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 2.534583, train error 89.80,  test loss 2.516075, test error 90.30
# Epoch     1, train loss 2.369126, train error 85.28,  test loss 2.358818, test error 88.10
# Epoch     2, train loss 2.274209, train error 81.88,  test loss 2.270112, test error 84.60
# Epoch     3, train loss 2.203840, train error 79.38,  test loss 2.204850, test error 82.30
# Epoch     4, train loss 2.146491, train error 78.43,  test loss 2.151521, test error 80.60
# Epoch     5, train loss 2.098061, train error 77.43,  test loss 2.107857, test error 79.40
# Epoch     6, train loss 2.056861, train error 76.80,  test loss 2.070356, test error 78.30
# Epoch     7, train loss 2.020005, train error 75.95,  test loss 2.035844, test error 77.30
# Epoch     8, train loss 1.987629, train error 75.32,  test loss 2.006402, test error 75.60
# Epoch     9, train loss 1.958305, train error 74.50,  test loss 1.979462, test error 75.10
# Epoch    10, train loss 1.944825, train error 74.18,  test loss 1.967258, test error 75.20
# Epoch    11, train loss 1.932021, train error 73.85,  test loss 1.955511, test error 75.00
# Epoch    12, train loss 1.919886, train error 73.22,  test loss 1.944291, test error 74.50
# Epoch    13, train loss 1.908187, train error 73.10,  test loss 1.933869, test error 74.60
# Epoch    14, train loss 1.897049, train error 72.88,  test loss 1.923560, test error 74.10
# Epoch    15, train loss 1.886243, train error 72.62,  test loss 1.913757, test error 74.20
# Epoch    16, train loss 1.876095, train error 72.43,  test loss 1.904391, test error 74.30
# Epoch    17, train loss 1.866233, train error 72.22,  test loss 1.895499, test error 73.30
# Epoch    18, train loss 1.856823, train error 72.05,  test loss 1.887180, test error 73.60
# Epoch    19, train loss 1.847646, train error 71.90,  test loss 1.878821, test error 73.60
# Epoch    20, train loss 1.843259, train error 71.75,  test loss 1.874678, test error 73.60
# Epoch    21, train loss 1.838957, train error 71.62,  test loss 1.870851, test error 73.70
# Epoch    22, train loss 1.834679, train error 71.47,  test loss 1.866970, test error 73.40
# Epoch    23, train loss 1.830536, train error 71.32,  test loss 1.863090, test error 73.40
# Epoch    24, train loss 1.826465, train error 71.10,  test loss 1.859295, test error 73.40
# Epoch    25, train loss 1.822412, train error 70.93,  test loss 1.855818, test error 73.30
# Epoch    26, train loss 1.818448, train error 70.90,  test loss 1.852264, test error 73.20
# Epoch    27, train loss 1.814590, train error 70.80,  test loss 1.848773, test error 72.90
# Epoch    28, train loss 1.810804, train error 70.75,  test loss 1.845516, test error 73.00
# Epoch    29, train loss 1.807019, train error 70.53,  test loss 1.841909, test error 73.00
# Epoch    30, train loss 1.805158, train error 70.47,  test loss 1.840292, test error 73.30
# Epoch    31, train loss 1.803308, train error 70.45,  test loss 1.838709, test error 73.20
# Epoch    32, train loss 1.801495, train error 70.32,  test loss 1.837022, test error 73.00
# Epoch    33, train loss 1.799688, train error 70.25,  test loss 1.835459, test error 73.10
# Epoch    34, train loss 1.797896, train error 70.15,  test loss 1.833887, test error 73.00
# Epoch    35, train loss 1.796115, train error 70.07,  test loss 1.832223, test error 72.80
# Epoch    36, train loss 1.794356, train error 70.05,  test loss 1.830677, test error 72.90
# Epoch    37, train loss 1.792593, train error 69.93,  test loss 1.829086, test error 72.90
# Epoch    38, train loss 1.790860, train error 69.85,  test loss 1.827602, test error 73.00
# Epoch    39, train loss 1.789146, train error 69.80,  test loss 1.826138, test error 72.90
# Epoch    40, train loss 1.788279, train error 69.80,  test loss 1.825356, test error 73.00
# Epoch    41, train loss 1.787437, train error 69.75,  test loss 1.824609, test error 73.00
# Epoch    42, train loss 1.786573, train error 69.68,  test loss 1.823805, test error 73.00
# Epoch    43, train loss 1.785737, train error 69.60,  test loss 1.823077, test error 73.00
# Epoch    44, train loss 1.784898, train error 69.68,  test loss 1.822335, test error 72.90
# Epoch    45, train loss 1.784054, train error 69.62,  test loss 1.821599, test error 72.90
# Epoch    46, train loss 1.783219, train error 69.53,  test loss 1.820830, test error 72.80
# Epoch    47, train loss 1.782393, train error 69.50,  test loss 1.820122, test error 72.80
# Epoch    48, train loss 1.781565, train error 69.43,  test loss 1.819368, test error 72.70
# Epoch    49, train loss 1.780736, train error 69.40,  test loss 1.818623, test error 72.70
# Epoch    50, train loss 1.780327, train error 69.40,  test loss 1.818280, test error 72.70
# Epoch    51, train loss 1.779915, train error 69.40,  test loss 1.817923, test error 72.70
# Epoch    52, train loss 1.779508, train error 69.43,  test loss 1.817564, test error 72.60
# Epoch    53, train loss 1.779099, train error 69.43,  test loss 1.817211, test error 72.60
# Epoch    54, train loss 1.778689, train error 69.40,  test loss 1.816844, test error 72.70
# Epoch    55, train loss 1.778283, train error 69.43,  test loss 1.816471, test error 72.60
# Epoch    56, train loss 1.777876, train error 69.40,  test loss 1.816107, test error 72.60
# Epoch    57, train loss 1.777471, train error 69.40,  test loss 1.815766, test error 72.60
# Epoch    58, train loss 1.777068, train error 69.38,  test loss 1.815388, test error 72.60
# Epoch    59, train loss 1.776664, train error 69.40,  test loss 1.815062, test error 72.50
# Epoch    60, train loss 1.776464, train error 69.38,  test loss 1.814868, test error 72.60
# Epoch    61, train loss 1.776263, train error 69.38,  test loss 1.814691, test error 72.50
# Epoch    62, train loss 1.776061, train error 69.38,  test loss 1.814514, test error 72.50
# Epoch    63, train loss 1.775859, train error 69.38,  test loss 1.814350, test error 72.40
# Epoch    64, train loss 1.775658, train error 69.38,  test loss 1.814162, test error 72.40
# Epoch    65, train loss 1.775458, train error 69.35,  test loss 1.813985, test error 72.40
# Epoch    66, train loss 1.775258, train error 69.35,  test loss 1.813816, test error 72.40
# Epoch    67, train loss 1.775057, train error 69.30,  test loss 1.813634, test error 72.40
# Epoch    68, train loss 1.774857, train error 69.30,  test loss 1.813453, test error 72.40
# Epoch    69, train loss 1.774656, train error 69.28,  test loss 1.813287, test error 72.40
# Epoch    70, train loss 1.774557, train error 69.28,  test loss 1.813198, test error 72.40
# Epoch    71, train loss 1.774457, train error 69.25,  test loss 1.813109, test error 72.40
# Epoch    72, train loss 1.774358, train error 69.25,  test loss 1.813025, test error 72.40
# Epoch    73, train loss 1.774257, train error 69.25,  test loss 1.812932, test error 72.40
# Epoch    74, train loss 1.774158, train error 69.25,  test loss 1.812846, test error 72.40
# Epoch    75, train loss 1.774058, train error 69.25,  test loss 1.812752, test error 72.40
# Epoch    76, train loss 1.773958, train error 69.28,  test loss 1.812670, test error 72.40
# Epoch    77, train loss 1.773859, train error 69.25,  test loss 1.812580, test error 72.40
# Epoch    78, train loss 1.773758, train error 69.22,  test loss 1.812495, test error 72.40
# Epoch    79, train loss 1.773660, train error 69.25,  test loss 1.812405, test error 72.30
# Epoch    80, train loss 1.773610, train error 69.25,  test loss 1.812358, test error 72.30
# Epoch    81, train loss 1.773560, train error 69.25,  test loss 1.812317, test error 72.30
# Epoch    82, train loss 1.773511, train error 69.25,  test loss 1.812274, test error 72.30
# Epoch    83, train loss 1.773461, train error 69.25,  test loss 1.812229, test error 72.30
# Epoch    84, train loss 1.773411, train error 69.25,  test loss 1.812188, test error 72.30
# Epoch    85, train loss 1.773362, train error 69.25,  test loss 1.812141, test error 72.30
# Epoch    86, train loss 1.773312, train error 69.25,  test loss 1.812101, test error 72.30
# Epoch    87, train loss 1.773262, train error 69.25,  test loss 1.812059, test error 72.30
# Epoch    88, train loss 1.773213, train error 69.25,  test loss 1.812009, test error 72.30
# Epoch    89, train loss 1.773164, train error 69.25,  test loss 1.811970, test error 72.30
# Epoch    90, train loss 1.773138, train error 69.25,  test loss 1.811947, test error 72.30
# Epoch    91, train loss 1.773114, train error 69.25,  test loss 1.811924, test error 72.30
# Epoch    92, train loss 1.773089, train error 69.25,  test loss 1.811904, test error 72.30
# Epoch    93, train loss 1.773064, train error 69.25,  test loss 1.811881, test error 72.30
# Epoch    94, train loss 1.773039, train error 69.25,  test loss 1.811859, test error 72.30
# Epoch    95, train loss 1.773014, train error 69.25,  test loss 1.811836, test error 72.30
# Epoch    96, train loss 1.772990, train error 69.25,  test loss 1.811816, test error 72.30
# Epoch    97, train loss 1.772965, train error 69.22,  test loss 1.811794, test error 72.30
# Epoch    98, train loss 1.772940, train error 69.22,  test loss 1.811771, test error 72.30
# Epoch    99, train loss 1.772915, train error 69.22,  test loss 1.811749, test error 72.30

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
