# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-agx_ldvb
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/pip-req-build-agx_ldvb
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (3.9.0)
# Requirement already satisfied: scipy in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from mnist1d==0.0.2.post16) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/antonis/miniforge3/envs/python3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_k),
                            torch.nn.ReLU(),
                            torch.nn.Linear(D_k,D_k),
                            torch.nn.ReLU(),
                            torch.nn.Linear(D_k,D_o))


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, torch.nn.Linear):
    torch.nn.init.kaiming_uniform_(layer_in.weight,  mode='fan_in', nonlinearity='relu')
    if layer_in.bias is not None:
              torch.nn.init.zeros_(layer_in.bias)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.586232, train error 62.75,  test loss 1.663584, test error 67.10
# Epoch     1, train loss 1.348772, train error 50.70,  test loss 1.466583, test error 58.70
# Epoch     2, train loss 1.166022, train error 43.40,  test loss 1.356826, test error 53.50
# Epoch     3, train loss 1.004016, train error 37.28,  test loss 1.242397, test error 48.50
# Epoch     4, train loss 0.888895, train error 31.55,  test loss 1.205224, test error 47.40
# Epoch     5, train loss 0.774849, train error 26.32,  test loss 1.118933, test error 44.30
# Epoch     6, train loss 0.688767, train error 23.70,  test loss 1.097523, test error 42.20
# Epoch     7, train loss 0.616015, train error 20.20,  test loss 1.059908, test error 41.10
# Epoch     8, train loss 0.555712, train error 18.60,  test loss 1.096866, test error 40.40
# Epoch     9, train loss 0.507212, train error 16.65,  test loss 1.129579, test error 40.70
# Epoch    10, train loss 0.402732, train error 11.43,  test loss 1.046337, test error 37.70
# Epoch    11, train loss 0.360148, train error 9.68,  test loss 1.069876, test error 37.60
# Epoch    12, train loss 0.330173, train error 8.97,  test loss 1.089112, test error 39.00
# Epoch    13, train loss 0.301205, train error 7.45,  test loss 1.078590, test error 36.80
# Epoch    14, train loss 0.282395, train error 7.30,  test loss 1.103322, test error 38.50
# Epoch    15, train loss 0.260563, train error 6.12,  test loss 1.129330, test error 38.20
# Epoch    16, train loss 0.231258, train error 4.78,  test loss 1.146292, test error 39.80
# Epoch    17, train loss 0.207286, train error 4.18,  test loss 1.129098, test error 36.70
# Epoch    18, train loss 0.194536, train error 3.57,  test loss 1.161609, test error 38.40
# Epoch    19, train loss 0.167199, train error 2.50,  test loss 1.165805, test error 38.60
# Epoch    20, train loss 0.150308, train error 1.95,  test loss 1.168646, test error 38.00
# Epoch    21, train loss 0.136081, train error 1.15,  test loss 1.175848, test error 36.10
# Epoch    22, train loss 0.128734, train error 0.80,  test loss 1.183393, test error 38.20
# Epoch    23, train loss 0.124897, train error 0.97,  test loss 1.207483, test error 37.30
# Epoch    24, train loss 0.114756, train error 0.70,  test loss 1.202082, test error 37.70
# Epoch    25, train loss 0.107980, train error 0.55,  test loss 1.231698, test error 37.80
# Epoch    26, train loss 0.104342, train error 0.57,  test loss 1.227761, test error 37.60
# Epoch    27, train loss 0.099467, train error 0.47,  test loss 1.234027, test error 37.70
# Epoch    28, train loss 0.095023, train error 0.28,  test loss 1.258827, test error 37.00
# Epoch    29, train loss 0.090387, train error 0.40,  test loss 1.269795, test error 37.20
# Epoch    30, train loss 0.084959, train error 0.22,  test loss 1.264842, test error 37.40
# Epoch    31, train loss 0.082313, train error 0.20,  test loss 1.271958, test error 36.80
# Epoch    32, train loss 0.080821, train error 0.20,  test loss 1.281472, test error 37.00
# Epoch    33, train loss 0.078649, train error 0.20,  test loss 1.273963, test error 37.50
# Epoch    34, train loss 0.076335, train error 0.20,  test loss 1.282880, test error 37.20
# Epoch    35, train loss 0.074991, train error 0.15,  test loss 1.300952, test error 37.70
# Epoch    36, train loss 0.073057, train error 0.12,  test loss 1.293055, test error 37.00
# Epoch    37, train loss 0.071313, train error 0.12,  test loss 1.302975, test error 37.50
# Epoch    38, train loss 0.070108, train error 0.18,  test loss 1.304034, test error 37.00
# Epoch    39, train loss 0.068226, train error 0.12,  test loss 1.315498, test error 37.60
# Epoch    40, train loss 0.067392, train error 0.12,  test loss 1.314416, test error 37.20
# Epoch    41, train loss 0.066513, train error 0.10,  test loss 1.313933, test error 37.40
# Epoch    42, train loss 0.065790, train error 0.10,  test loss 1.319895, test error 37.00
# Epoch    43, train loss 0.064953, train error 0.12,  test loss 1.323065, test error 37.40
# Epoch    44, train loss 0.064408, train error 0.10,  test loss 1.323971, test error 37.20
# Epoch    45, train loss 0.063647, train error 0.10,  test loss 1.324700, test error 37.50
# Epoch    46, train loss 0.063032, train error 0.10,  test loss 1.327411, test error 37.20
# Epoch    47, train loss 0.062316, train error 0.07,  test loss 1.331093, test error 37.20
# Epoch    48, train loss 0.061606, train error 0.05,  test loss 1.332826, test error 37.20
# Epoch    49, train loss 0.061218, train error 0.05,  test loss 1.332480, test error 37.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
